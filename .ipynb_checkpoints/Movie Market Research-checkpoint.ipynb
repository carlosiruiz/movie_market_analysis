# %% [markdown]
# # Movie Market Research

# %% [markdown]
# #### API Loading

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import seaborn as sns

# %%
# iterate through API requests. Records are stored in 'collected_data'
# this cell takes approximately 5 minutes to run

collected_data = []

for i in range(1,500,1):
    request_string = "https://api.themoviedb.org/3/discover/movie?api_key=afc7201593c1f2fc08c24eec64fabc88&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&primary_release_date.lte=2019-12-30&primary_release_date.gte=2000-01-01&page="+str(i)
    data = requests.get(request_string)
    data = data.json()['results']
    for item in data:
        collected_data.append(item)

# %%
#load data into dataframe
df = pd.DataFrame(collected_data)

# %%
# The 'discover' API is missing budget, revenue, imdb_id, and runtime
# these can be pulled from the 'movie' API call. this cell prepares for the next for loop to pull this required data
budget = []
imdb_id = []
revenue = []
runtime = []
production_companies = []
production_countries = []
genres = []

# %%
#create a list of tmdb-movie-ids to iterate through. each id will be used in its own API call
#for each movie_id defined above, call API to to retrieve budget, revenue, imdb_id, runtime.
#tmdb data structure isn't uniform. movie dictionaries do not necessarily have all keys.
#to get around this, we used try/except
#this cell takes about 30 minutes to run
movie_ids = list(df['id'])
for movie_id in movie_ids:
    request_string = "https://api.themoviedb.org/3/movie/"+str(movie_id)+"?api_key=afc7201593c1f2fc08c24eec64fabc88&language=en-US"
    data = requests.get(request_string)
    data = data.json()
    try:
        budget.append(data['budget'])
    except:
        budget.append(" ")
    try:
        imdb_id.append(data['imdb_id'])
    except:
        imdb_id.append(" ")
    try:
        revenue.append(data['revenue'])
    except:
        revenue.append(" ")
    try:
        runtime.append(data['runtime'])
    except:
        runtime.append(" ")
    try:
        production_companies.append(data['production_companies'])
    except:
        production_companies.append(" ")
    try:
        production_countries.append(data['production_countries'])
    except:
        production_countries.append(" ")
    try:
        genres.append(data['genres'])
    except:
        genres.append(" ")

# %%
# Finally append the new columns to the final DataFrame
df['budget']=budget
df['imdb_id']=imdb_id
df['runtime']= runtime 
df['production_companies']=production_companies
df['production_countries']=production_companies
df['genres']=genres
df['revenue']=revenue

# %%
# Separating our release date into year and month.
df['release_year'] = df['release_date'].apply(lambda x: int(x[0:4]))
df['release_month'] = df['release_date'].apply(lambda x: int(x[5:7]))
df.drop('release_date',axis= 1,inplace=True)

# %%
# Removing unnecessary information
df.drop(['poster_path','video','backdrop_path','adult','original_language','genre_ids','original_title'],axis=1,inplace=True)

# Rearranging columns with a more easy to read order.
new_col=[ 'id', 'title', 'imdb_id','genres','overview', 'budget', 'release_year','release_month','popularity', 'vote_count','vote_average','revenue', 'runtime','production_companies', 'production_countries']
df=df[new_col]

# Resetting the index to maintain cohesive rows.
df.reset_index(drop=True,inplace=True)

# %%
# Exporting main DF so API is not needed to run.
df.to_csv('tmdb_master.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9980 entries, 0 to 9979
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9980 non-null   int64
#  1   title                 9980 non-null   object
#  2   imdb_id               9965 non-null   object
#  3   genres                9980 non-null   object
#  4   overview              9980 non-null   object
#  5   budget                9980 non-null   object
#  6   release_year          9980 non-null   int64
#  7   release_month         9980 non-null   int64
#  8   popularity            9980 non-null   float64
#  9   vote_count            9980 non-null   int64
#  10  vote_average          9980 non-null   float64
#  11  revenue               9980 non-null   object
#  12  runtime               9980 non-null   object
#  13  production_companies  9980 non-null   object
#  14  production_countries  9980 non-null   object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Asking Questions

# %% [markdown]
# #### Who are the most  popular production companies in the last 20 years?

# %%
# Load DataFrame and assess values
companies_df=pd.read_csv('tmdb_master.csv')
companies_df.reset_index(drop=True,inplace=True)
companies_df.sort_values('popularity',ascending=False).head(5)
# Out:
#         id                       title    imdb_id  \
# 0   475557                       Joker  tt7286456
# 1   299536      Avengers: Infinity War  tt4154756
# 4    27205                   Inception  tt1375666
# 2   271110  Captain America: Civil War  tt3498820
# 12  569715     Delicious Three Sisters        NaN
#
#                                                genres  \
# 0   [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 12                 [{'id': 10749, 'name': 'Romance'}]
#
#                                              overview     budget  \
# 0   During the 1980s, a failed stand-up comedian i...   55000000
# 1   As the Avengers and their allies have continue...  300000000
# 4   Cobb, a skilled thief who commits corporate es...  160000000
# 2   Following the events of Age of Ultron, the col...  250000000
# 12  The gentle gesture of the three sisters surrou...          0
#
#     release_year  release_month  popularity  vote_count  vote_average  \
# 0           2019             10      80.757       14346           8.2
# 1           2018              4      77.294       19348           8.3
# 4           2010              7      69.553       26852           8.3
# 2           2016              4      69.266       16650           7.4
# 12          2018             10      67.246           3           4.0
#
#        revenue runtime                               production_companies  \
# 0   1074251311     122  [{'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp...
# 1   2046239637     149  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 4    825532764     148  [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8D...
# 2   1153296293     147  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 12           0      81                                                 []
#
#                                  production_countries
# 0   [{'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp...
# 1   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 4   [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8D...
# 2   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 12                                                 []

# %%
def namelist(cell):
    name_list=[]
    for i in cell:
        name_list.append(i['name'])
    return name_list

# %%
def list_to_dic(column,df):
    """
    list_to_dic(string,dataframe)
    
    list_to_dic takes in the column that we want to create a dictionary that counts the repetition of values for 
    said word.
    list_to_dic creates a column in the provided DataFrame with the list of unique values of said column string,
    then it evaluates the string and teruns a dictionary list with all unique words and their count for the column.
    
    """
    
    column_name=column+'_list'
    df[column_name]=df[column].apply(namelist)
    company_list=list(df[column_name])
    dup_list=[]
    
    for a in company_list:
        for i in a:
            dup_list.append(i)
    unique_list=list(set(dup_list))
    company_dictionary={}
    
    for company in unique_list:
        company_dictionary[company]=0
    
    for company in dup_list:
        company_dictionary[company]=company_dictionary[company]+1
    return company_dictionary

# %%
# def namelist(cell):
#     name_list=[]
#     for i in cell:
#         name_list.append(i['name'])
#     return name_list

# companies_df['production_list']=companies_df.production_companies.apply(namelist)
# company_list=list(companies_df.production_list)
# dup_list=[]

# for a in company_list:
#     for i in a:
#         dup_list.append(i)
# unique_list=list(set(dup_list))
# company_dictionary={}
    
# for company in unique_list:
#     company_dictionary[company]=0

# for company in dup_list:
#     company_dictionary[company]=company_dictionary[company]+1

# %%
companies_df.production_companies[0]
# Out:
# "[{'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 83036, 'logo_path': None, 'name': 'Joint Effort', 'origin_country': 'US'}, {'id': 79, 'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png', 'name': 'Village Roadshow Pictures', 'origin_country': 'US'}, {'id': 13240, 'logo_path': '/aTc07YaNHo8WNgkQSnvLmG6w4nW.png', 'name': 'Bron Studios', 'origin_country': 'CA'}, {'id': 53152, 'logo_path': '/8XHHLy8GGTuHM9JMzYjGqxB6oPa.png', 'name': 'Creative Wealth Media Finance', 'origin_country': 'CA'}, {'id': 128064, 'logo_path': None, 'name': 'DC Films', 'origin_country': 'US'}, {'id': 57409, 'logo_path': None, 'name': '22 & Indiana Pictures', 'origin_country': ''}]"

# %%
#creating dictionaries from strings
companies_df.production_companies = [eval(key) for key in companies_df.production_companies]
companies_df.production_countries= [eval(key) for key in companies_df.production_countries]
companies_df.genres= [eval(key) for key in companies_df.genres]

# %%
# Out:
#           id                                              title imdb_id  \
# 12    569715                            Delicious Three Sisters
# 1678  567604                               Once Upon a Deadpool
# 2842  452251                      Beauty Salon: Special Service
# 3084  418827                           Sister's Younger Husband
# 5166  101907                                      Hulk vs. Thor
# 5205  372049                                   My Friend's Wife
# 6269   15257                                 Hulk vs. Wolverine
# 6961  409276                        What a Good Secretary Wants
# 6990  272364                                       Kuliah Cinta
# 8272  387824                                       Mom's Friend
# 9069  409387               Sex: A Relationship and Not Marriage
# 9190   27980  Nine Inch Nails: Another Version of the Truth ...
#
#                                                  genres  \
# 12                   [{'id': 10749, 'name': 'Romance'}]
# 1678  [{'id': 35, 'name': 'Comedy'}, {'id': 28, 'nam...
# 2842  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 3084  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 5166  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
# 5205                 [{'id': 10749, 'name': 'Romance'}]
# 6269  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 6961  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 6990  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 8272  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 9069  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 9190                   [{'id': 10402, 'name': 'Music'}]
#
#                                                overview budget  release_year  \
# 12    The gentle gesture of the three sisters surrou...      0          2018
# 1678  A kidnapped Fred Savage is forced to endure De...      0          2018
# 2842  A legendary beauty salon that is sure to becom...      0          2016
# 3084  A sexy brother-in-law approached her? And he’s...      0          2016
# 5166  For ages, Odin has protected his kingdom of As...      0          2009
# 5205  I want to spend all night with my friend's wif...      0          2015
# 6269  Department H sends in Wolverine to track down ...      0          2009
# 6961  The silent secret of the perfect woman.  Geniu...      0          2016
# 6990  A romantic comedy about teenage life on campus...      0          2004
# 8272  Seong Soo, a twenty years old boy, decided to ...      0          2015
# 9069  The life story of a woman who doesn't want to ...      0          2016
# 9190  Filmed in Sacramento, Portland, and Victoria b...      0          2009
#
#       release_month  popularity  vote_count  vote_average revenue runtime  \
# 12               10      67.246           3           4.0       0      81
# 1678             12      17.528         389           6.9       0     117
# 2842             12      13.395           4           5.5       0      81
# 3084             10      15.908           6           5.0       0      75
# 5166              1       8.420         132           6.5       0      41
# 5205             12       9.231           2           7.0       0      80
# 6269              1       7.050         134           6.9       0      38
# 6961              5       7.522           1           3.0       0      71
# 6990              1       9.511           1           2.0       0       0
# 8272              8       7.243           4           6.6       0      91
# 9069              4       6.930           4           6.3       0     109
# 9190             12       8.913           4           7.6       0     134
#
#                                    production_companies  \
# 12                                                   []
# 1678  [{'id': 7505, 'logo_path': '/837VMM4wOkODc1idN...
# 2842                                                 []
# 3084                                                 []
# 5166  [{'id': 13252, 'logo_path': '/aGeUvfSNA8gRl6Zj...
# 5205                                                 []
# 6269  [{'id': 1632, 'logo_path': '/cisLn1YAUuptXVBa0...
# 6961                                                 []
# 6990                                                 []
# 8272                                                 []
# 9069                                                 []
# 9190                                                 []
#
#                                    production_countries
# 12                                                   []
# 1678  [{'id': 7505, 'logo_path': '/837VMM4wOkODc1idN...
# 2842                                                 []
# 3084                                                 []
# 5166  [{'id': 13252, 'logo_path': '/aGeUvfSNA8gRl6Zj...
# 5205                                                 []
# 6269  [{'id': 1632, 'logo_path': '/cisLn1YAUuptXVBa0...
# 6961                                                 []
# 6990                                                 []
# 8272                                                 []
# 9069                                                 []
# 9190                                                 []

# %%
# Out:
# [{'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 83036, 'logo_path': None, 'name': 'Joint Effort', 'origin_country': 'US'}, {'id': 79, 'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png', 'name': 'Village Roadshow Pictures', 'origin_country': 'US'}, {'id': 13240, 'logo_path': '/aTc07YaNHo8WNgkQSnvLmG6w4nW.png', 'name': 'Bron Studios', 'origin_country': 'CA'}, {'id': 53152, 'logo_path': '/8XHHLy8GGTuHM9JMzYjGqxB6oPa.png', 'name': 'Creative Wealth Media Finance', 'origin_country': 'CA'}, {'id': 128064, 'logo_path': None, 'name': 'DC Films', 'origin_country': 'US'}, {'id': 57409, 'logo_path': None, 'name': '22 & Indiana Pictures', 'origin_country': ''}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}]
# [{'id': 29924, 'logo_path': None, 'name': 'Fresh Film', 'origin_country': 'RU'}, {'id': 76049, 'logo_path': '/tam9pIV4QK1ZPwdxBgtVkK1WTYC.png', 'name': 'Cinema Fund', 'origin_country': 'RU'}, {'id': 54307, 'logo_path': '/c6zhUONn8UMP6vdDHXrxpGxuzh2.png', 'name': 'Mars Media Entertainment', 'origin_country': 'RU'}, {'id': 87064, 'logo_path': None, 'name': 'Big Cinema House', 'origin_country': 'RU'}, {'id': 76352, 'logo_path': None, 'name': 'Fond kino', 'origin_country': ''}, {'id': 131715, 'logo_path': None, 'name': 'Argunov Studio', 'origin_country': ''}, {'id': 3419, 'logo_path': '/byrxE2pJD9JLyBCIzyK0pYVanyG.png', 'name': 'Central Partnership', 'origin_country': 'RU'}]
# [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png', 'name': 'Legendary Entertainment', 'origin_country': 'US'}, {'id': 9996, 'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png', 'name': 'Syncopy', 'origin_country': 'GB'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}]
# [{'id': 82819, 'logo_path': '/5Z8WWr0Lf1tInVWwJsxPP0uMz9a.png', 'name': 'Skydance Media', 'origin_country': 'US'}, {'id': 4, 'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png', 'name': 'Paramount', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 84041, 'logo_path': '/XmHMPGzdI5c4WGX1YlxU4s2v7T.png', 'name': 'Pascal Pictures', 'origin_country': 'US'}, {'id': 34, 'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png', 'name': 'Sony Pictures', 'origin_country': 'US'}, {'id': 86561, 'logo_path': None, 'name': 'Stereo D', 'origin_country': 'US'}]
# [{'id': 7036, 'logo_path': '/javbyY0ZCvlFJtly3tpZqf2NwLX.png', 'name': 'CJ Entertainment', 'origin_country': 'KR'}, {'id': 4399, 'logo_path': '/7bWmbWfxFNSGTCjLHkHn3UjspZS.png', 'name': 'Barunson E&A', 'origin_country': 'KR'}]
# [{'id': 490, 'logo_path': None, 'name': 'New Regency Productions', 'origin_country': 'US'}, {'id': 79963, 'logo_path': None, 'name': 'Keep Your Head', 'origin_country': ''}, {'id': 73492, 'logo_path': None, 'name': 'MadRiver Pictures', 'origin_country': ''}, {'id': 81, 'logo_path': '/8wOfUhA7vwU2gbPjQy7Vv3EiF0o.png', 'name': 'Plan B Entertainment', 'origin_country': 'US'}, {'id': 30666, 'logo_path': '/g8LmDZVFWDRJW72sj0nAj1gh8ac.png', 'name': 'RT Features', 'origin_country': 'BR'}, {'id': 30148, 'logo_path': '/zerhOenUD6CkH8SMgZUhrDkOs4w.png', 'name': 'Bona Film Group', 'origin_country': 'CN'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}]
# [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 437, 'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png', 'name': 'Heyday Films', 'origin_country': 'GB'}, {'id': 436, 'logo_path': '/A7WCkG3F0NFvjGCwUnclpGdIu9E.png', 'name': '1492 Pictures', 'origin_country': 'US'}]
# [{'id': 108812, 'logo_path': None, 'name': 'Pad Thai Pictures', 'origin_country': ''}, {'id': 108813, 'logo_path': None, 'name': 'Filmsmith Production & Management', 'origin_country': ''}]
# [{'id': 7117, 'logo_path': None, 'name': 'Les Films Velvet', 'origin_country': 'FR'}, {'id': 591, 'logo_path': '/q5I5RDwMEiqoNmfaJgd2LraEOJY.png', 'name': 'France 3 Cinéma', 'origin_country': 'FR'}, {'id': 201, 'logo_path': '/6UIpEURdjnmcJPwgTDRzVRuwADr.png', 'name': 'ARTE', 'origin_country': 'FR'}, {'id': 94, 'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png', 'name': 'ARTE France Cinéma', 'origin_country': 'FR'}]
# []
# [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 11, 'logo_path': '/6FAuASQHybRkZUk08p9PzSs9ezM.png', 'name': 'WingNut Films', 'origin_country': 'NZ'}, {'id': 12, 'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png', 'name': 'New Line Cinema', 'origin_country': 'US'}, {'id': 7413, 'logo_path': None, 'name': '3Foot7', 'origin_country': 'NZ'}, {'id': 21, 'logo_path': '/mjofSXiHpG5t6KYmU4l4FrUhT7m.png', 'name': 'Metro-Goldwyn-Mayer', 'origin_country': 'US'}]
# [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png', 'name': 'Legendary Entertainment', 'origin_country': 'US'}, {'id': 9996, 'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png', 'name': 'Syncopy', 'origin_country': 'GB'}, {'id': 13769, 'logo_path': None, 'name': 'Lynda Obst Productions', 'origin_country': ''}]
# [{'id': 1632, 'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png', 'name': 'Lionsgate', 'origin_country': 'US'}, {'id': 2531, 'logo_path': '/pC2iDCDCvV85vOBP7a5Ukxuc0Du.png', 'name': 'MRC', 'origin_country': 'US'}, {'id': 37871, 'logo_path': None, 'name': 'T-Street', 'origin_country': 'US'}]
# [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 12236, 'logo_path': '/uV6QBPdn3MjQzAFdgEel6od7geg.png', 'name': 'Blinding Edge Pictures', 'origin_country': 'US'}, {'id': 3172, 'logo_path': '/kDedjRZwO8uyFhuHamomOhN6fzG.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}]
# [{'id': 491, 'logo_path': '/rUp0lLKa1pr4UsPm8fgzmnNGxtq.png', 'name': 'Summit Entertainment', 'origin_country': 'US'}, {'id': 12292, 'logo_path': '/llGRXF5WYUW2fzXg0ebCoKMXjmT.png', 'name': 'Temple Hill Entertainment', 'origin_country': 'US'}, {'id': 5218, 'logo_path': '/dhb42ugM9DzSpDctTWCtABPVOW4.png', 'name': 'Imprint Entertainment', 'origin_country': 'US'}, {'id': 4000, 'logo_path': None, 'name': 'Maverick Films', 'origin_country': 'US'}, {'id': 57750, 'logo_path': None, 'name': 'Twilight Productions', 'origin_country': 'US'}]
# [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZcyE8pDb.png', 'name': 'Lucasfilm Ltd.', 'origin_country': 'US'}, {'id': 11461, 'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png', 'name': 'Bad Robot', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 120404, 'logo_path': None, 'name': 'British Film Commission', 'origin_country': ''}]
# [{'id': 1522, 'logo_path': '/8uaoEVgNxFH0R94O53gUiByahVr.png', 'name': 'Neal Street Productions', 'origin_country': 'GB'}, {'id': 7, 'logo_path': '/vru2SssLX3FPhnKZGtYw00pVIS9.png', 'name': 'DreamWorks Pictures', 'origin_country': 'US'}, {'id': 114732, 'logo_path': '/tNCbisMxO5mX2X2bOQxHHQZVYnT.png', 'name': 'New Republic Pictures', 'origin_country': 'US'}, {'id': 121685, 'logo_path': '/bAO6cpKP9qoqHoDn4oUjWjZ5auq.png', 'name': 'Amblin Partners', 'origin_country': 'US'}, {'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 133323, 'logo_path': None, 'name': 'Moving Picture Company', 'origin_country': ''}, {'id': 7294, 'logo_path': '/kK4PRgceWp9KNrycD8xx8seWxYU.png', 'name': 'Reliance Entertainment', 'origin_country': 'IN'}, {'id': 103476, 'logo_path': None, 'name': 'Mogambo', 'origin_country': ''}, {'id': 8582, 'logo_path': None, 'name': 'The Canadian Film or Video Production Tax Credit (CPTC)', 'origin_country': 'CA'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 84041, 'logo_path': '/XmHMPGzdI5c4WGX1YlxU4s2v7T.png', 'name': 'Pascal Pictures', 'origin_country': 'US'}, {'id': 34034, 'logo_path': None, 'name': 'LStar Capital', 'origin_country': 'US'}, {'id': 34, 'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png', 'name': 'Sony Pictures', 'origin_country': 'US'}]
# [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4HuilrcV0yujsZ9.png', 'name': 'Walt Disney Animation Studios', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}]
# [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 7297, 'logo_path': '/l29JYQVZbTcjZXoz4CUYFpKRmM3.png', 'name': 'Fairview Entertainment', 'origin_country': 'US'}]
# [{'id': 431, 'logo_path': None, 'name': "The Donners' Company", 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}, {'id': 28788, 'logo_path': None, 'name': 'Genre Films', 'origin_country': 'US'}, {'id': 9168, 'logo_path': '/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png', 'name': 'Bad Hat Harry Productions', 'origin_country': 'US'}, {'id': 7505, 'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png', 'name': 'Marvel Entertainment', 'origin_country': 'US'}, {'id': 112049, 'logo_path': None, 'name': 'Kinberg Genre', 'origin_country': ''}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}]
# [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 436, 'logo_path': '/A7WCkG3F0NFvjGCwUnclpGdIu9E.png', 'name': '1492 Pictures', 'origin_country': 'US'}, {'id': 437, 'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png', 'name': 'Heyday Films', 'origin_country': 'GB'}]
# [{'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png', 'name': 'Legendary Entertainment', 'origin_country': 'US'}, {'id': 9996, 'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png', 'name': 'Syncopy', 'origin_country': 'GB'}, {'id': 118865, 'logo_path': None, 'name': 'Isobel Griffiths', 'origin_country': 'GB'}, {'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}]
# [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4HuilrcV0yujsZ9.png', 'name': 'Walt Disney Animation Studios', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}]
# [{'id': 2723, 'logo_path': None, 'name': 'Lin Pictures', 'origin_country': 'US'}, {'id': 12, 'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png', 'name': 'New Line Cinema', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 829, 'logo_path': '/mzpAmEQ5P1gFvdRoNyCk9q8ngiv.png', 'name': 'Vertigo Entertainment', 'origin_country': 'US'}, {'id': 87671, 'logo_path': '/kEEGB5Z2XLYeR3AMt3Qds7vMnvM.png', 'name': 'KatzSmith Productions', 'origin_country': 'US'}]
# [{'id': 9383, 'logo_path': '/ppeMh4iZJQUMm1nAjRALeNhWDfU.png', 'name': 'Blue Sky Studios', 'origin_country': 'US'}, {'id': 11749, 'logo_path': '/5AzTeZkSCFhiGZ86g2nz8SAHtgy.png', 'name': '20th Century Fox Animation', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}]
# [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 16314, 'logo_path': None, 'name': 'Roth Films', 'origin_country': 'US'}]
# [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 2723, 'logo_path': None, 'name': 'Lin Pictures', 'origin_country': 'US'}, {'id': 118854, 'logo_path': '/g9LPNlQFoDcHjfnvrEqFmeIaDrZ.png', 'name': 'Rideback', 'origin_country': 'US'}, {'id': 2527, 'logo_path': '/osO7TGmlRMistSQ5JZusPhbKUHk.png', 'name': 'Marc Platt Productions', 'origin_country': 'US'}]
# [{'id': 574, 'logo_path': '/iB6GjNVHs5hOqcEYt2rcjBqIjki.png', 'name': 'Lightstorm Entertainment', 'origin_country': 'US'}, {'id': 82819, 'logo_path': '/5Z8WWr0Lf1tInVWwJsxPP0uMz9a.png', 'name': 'Skydance Media', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}, {'id': 4, 'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png', 'name': 'Paramount', 'origin_country': 'US'}, {'id': 81620, 'logo_path': '/gNp4dfuBOXmVWdGKb63NfbFNbFi.png', 'name': 'Tencent Pictures', 'origin_country': 'CN'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}, {'id': 122144, 'logo_path': None, 'name': 'Instituto de la Cinematografía y de las Artes Audiovisuales (ICAA)', 'origin_country': ''}, {'id': 130088, 'logo_path': None, 'name': 'Ministry of Finance of Spain', 'origin_country': 'ES'}, {'id': 11408, 'logo_path': None, 'name': 'Ministerio de Cultura', 'origin_country': ''}, {'id': 48581, 'logo_path': '/yqf1h4IKBKBEAjUtrnp0FRVBv76.png', 'name': 'Hungarian National Film Fund', 'origin_country': 'HU'}, {'id': 2735, 'logo_path': None, 'name': 'Mid Atlantic Films', 'origin_country': 'HU'}]
# [{'id': 39649, 'logo_path': None, 'name': 'Huayi Brothers Media', 'origin_country': 'CN'}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 11029, 'logo_path': '/aEqqnFZjCW10ODE4TYQ1qkjvokr.png', 'name': 'QED International', 'origin_country': 'US'}, {'id': 34034, 'logo_path': None, 'name': 'LStar Capital', 'origin_country': 'US'}, {'id': 47169, 'logo_path': None, 'name': 'Le Grisbi Productions', 'origin_country': 'US'}, {'id': 16312, 'logo_path': None, 'name': 'Crave Films', 'origin_country': 'US'}, {'id': 34, 'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png', 'name': 'Sony Pictures', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}]
# [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 2251, 'logo_path': '/6l16UFSkZ1oPpyBYaILgffFZlTc.png', 'name': 'Sony Pictures Animation', 'origin_country': 'US'}, {'id': 7505, 'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png', 'name': 'Marvel Entertainment', 'origin_country': 'US'}, {'id': 14439, 'logo_path': None, 'name': 'Arad Productions', 'origin_country': 'US'}, {'id': 77973, 'logo_path': None, 'name': 'Lord Miller', 'origin_country': 'US'}, {'id': 84041, 'logo_path': '/XmHMPGzdI5c4WGX1YlxU4s2v7T.png', 'name': 'Pascal Pictures', 'origin_country': 'US'}, {'id': 34, 'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png', 'name': 'Sony Pictures', 'origin_country': 'US'}]
# [{'id': 107107, 'logo_path': None, 'name': 'CalMaple Films', 'origin_country': 'US'}, {'id': 107108, 'logo_path': '/5mxc7uNtFOZm2ly0BxixxGPvPlb.png', 'name': 'Wattpad', 'origin_country': 'US'}, {'id': 2378, 'logo_path': '/5xDJwLbyyt8IXuRAsR7kVibLDYF.png', 'name': 'Offspring Entertainment', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 4, 'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png', 'name': 'Paramount', 'origin_country': 'US'}, {'id': 7297, 'logo_path': '/l29JYQVZbTcjZXoz4CUYFpKRmM3.png', 'name': 'Fairview Entertainment', 'origin_country': 'US'}]
# [{'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png', 'name': 'Pixar', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}]
# [{'id': 491, 'logo_path': '/rUp0lLKa1pr4UsPm8fgzmnNGxtq.png', 'name': 'Summit Entertainment', 'origin_country': 'US'}, {'id': 3528, 'logo_path': '/cCzCClIzIh81Fa79hpW5nXoUsHK.png', 'name': 'Thunder Road', 'origin_country': 'US'}, {'id': 113619, 'logo_path': None, 'name': '87Eleven Productions', 'origin_country': ''}, {'id': 1632, 'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png', 'name': 'Lionsgate', 'origin_country': 'US'}]
# [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 73669, 'logo_path': '/usfW3lL4cL8eatNAlhfRrryyKkK.png', 'name': 'Seven Bucks Productions', 'origin_country': 'US'}, {'id': 40268, 'logo_path': '/shdAxUj8uF6exNLrF0kSqYVxCzG.png', 'name': 'HartBeat Productions', 'origin_country': 'US'}, {'id': 53462, 'logo_path': None, 'name': 'Matt Tolmach Productions', 'origin_country': 'US'}, {'id': 2550, 'logo_path': None, 'name': 'Teitler Film', 'origin_country': ''}, {'id': 34, 'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png', 'name': 'Sony Pictures', 'origin_country': 'US'}]
# [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 437, 'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png', 'name': 'Heyday Films', 'origin_country': 'GB'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}]
# [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 6125, 'logo_path': '/tVPmo07IHhBs4HuilrcV0yujsZ9.png', 'name': 'Walt Disney Animation Studios', 'origin_country': 'US'}]
# [{'id': 2537, 'logo_path': None, 'name': 'Kennedy Miller Productions', 'origin_country': 'AU'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 41624, 'logo_path': '/wzKxIeQKlMP0y5CaAw25MD6EQmf.png', 'name': 'RatPac-Dune Entertainment', 'origin_country': 'US'}, {'id': 79, 'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png', 'name': 'Village Roadshow Pictures', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}]
# [{'id': 43, 'logo_path': '/4RgIPr55kBakgupWkzdDxqXJEqr.png', 'name': 'Fox Searchlight Pictures', 'origin_country': 'US'}, {'id': 6510, 'logo_path': None, 'name': 'Defender Films', 'origin_country': 'NZ'}, {'id': 76342, 'logo_path': '/i53Cvs0mWLEhrRaPOpUXj4lJxDJ.png', 'name': 'Piki Films', 'origin_country': 'NZ'}]
# [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZcyE8pDb.png', 'name': 'Lucasfilm Ltd.', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 47706, 'logo_path': None, 'name': 'Allison Shearmur Productions', 'origin_country': 'US'}, {'id': 23, 'logo_path': '/mkxNjThahj5pvntvYKVpMbWXm3D.png', 'name': 'Imagine Entertainment', 'origin_country': 'US'}]
# [{'id': 2849, 'logo_path': '/cN3JNIKawjOMtfk0GBVIbsx69bg.png', 'name': 'BONES', 'origin_country': 'JP'}]
# [{'id': 1645, 'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png', 'name': 'Scott Free Productions', 'origin_country': 'GB'}, {'id': 2735, 'logo_path': None, 'name': 'Mid Atlantic Films', 'origin_country': 'HU'}, {'id': 6408, 'logo_path': None, 'name': 'International Traders', 'origin_country': ''}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}, {'id': 28788, 'logo_path': None, 'name': 'Genre Films', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}]
# [{'id': 290, 'logo_path': '/Q8mw2AOQQc8Qg0uNwLWq86DVZv.png', 'name': 'Ingenious Media', 'origin_country': 'GB'}, {'id': 3672, 'logo_path': '/5VWXJgYYrJZUE0hixvBdVfGSfmo.png', 'name': 'Gotham Group', 'origin_country': 'US'}, {'id': 8569, 'logo_path': None, 'name': 'Dayday Films', 'origin_country': 'GB'}, {'id': 12292, 'logo_path': '/llGRXF5WYUW2fzXg0ebCoKMXjmT.png', 'name': 'Temple Hill Entertainment', 'origin_country': 'US'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}]
# [{'id': 444, 'logo_path': '/42UPdZl6B2cFXgNUASR8hSt9mpS.png', 'name': 'Dune Entertainment', 'origin_country': 'US'}, {'id': 574, 'logo_path': '/iB6GjNVHs5hOqcEYt2rcjBqIjki.png', 'name': 'Lightstorm Entertainment', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}, {'id': 290, 'logo_path': '/Q8mw2AOQQc8Qg0uNwLWq86DVZv.png', 'name': 'Ingenious Media', 'origin_country': 'GB'}]
# [{'id': 2598, 'logo_path': '/i42C5gRq7XqlG4S9vkchuJZfrBn.png', 'name': 'Hasbro', 'origin_country': ''}, {'id': 4, 'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png', 'name': 'Paramount', 'origin_country': 'US'}, {'id': 57031, 'logo_path': None, 'name': 'Allspark Pictures', 'origin_country': ''}, {'id': 6734, 'logo_path': None, 'name': 'Bay Films', 'origin_country': ''}, {'id': 435, 'logo_path': '/AjzK0s2w1GtLfR4hqCjVSYi0Sr8.png', 'name': 'Di Bonaventura Pictures', 'origin_country': 'US'}, {'id': 81620, 'logo_path': '/gNp4dfuBOXmVWdGKb63NfbFNbFi.png', 'name': 'Tencent Pictures', 'origin_country': 'CN'}, {'id': 38831, 'logo_path': None, 'name': 'Tom DeSanto/Don Murphy Production', 'origin_country': ''}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 4, 'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png', 'name': 'Paramount', 'origin_country': 'US'}]
# [{'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 41624, 'logo_path': '/wzKxIeQKlMP0y5CaAw25MD6EQmf.png', 'name': 'RatPac-Dune Entertainment', 'origin_country': 'US'}, {'id': 9995, 'logo_path': '/mAIGhOYhN4N2N0F7p4dbKhgXf3l.png', 'name': 'Cruel & Unusual Films', 'origin_country': 'US'}, {'id': 507, 'logo_path': '/z7H707qUWigbjHnJDMfj6QITEpb.png', 'name': 'Atlas Entertainment', 'origin_country': 'US'}, {'id': 102618, 'logo_path': None, 'name': 'Lensbern Productions', 'origin_country': 'US'}, {'id': 444, 'logo_path': '/42UPdZl6B2cFXgNUASR8hSt9mpS.png', 'name': 'Dune Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 128064, 'logo_path': None, 'name': 'DC Films', 'origin_country': 'US'}, {'id': 8582, 'logo_path': None, 'name': 'The Canadian Film or Video Production Tax Credit (CPTC)', 'origin_country': 'CA'}, {'id': 9996, 'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png', 'name': 'Syncopy', 'origin_country': 'GB'}]
# [{'id': 31828, 'logo_path': None, 'name': 'Avi Arad Productions', 'origin_country': 'US'}, {'id': 53462, 'logo_path': None, 'name': 'Matt Tolmach Productions', 'origin_country': 'US'}, {'id': 84041, 'logo_path': '/XmHMPGzdI5c4WGX1YlxU4s2v7T.png', 'name': 'Pascal Pictures', 'origin_country': 'US'}, {'id': 7505, 'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png', 'name': 'Marvel Entertainment', 'origin_country': 'US'}, {'id': 81620, 'logo_path': '/gNp4dfuBOXmVWdGKb63NfbFNbFi.png', 'name': 'Tencent Pictures', 'origin_country': 'CN'}]
# [{'id': 38145, 'logo_path': None, 'name': 'Bristol Automotive', 'origin_country': 'US'}, {'id': 22146, 'logo_path': '/jPBtpMh0AUFqf9yfOJXer9d5Rei.png', 'name': 'Black Bear Pictures', 'origin_country': 'US'}]
# [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 3172, 'logo_path': '/kDedjRZwO8uyFhuHamomOhN6fzG.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}, {'id': 12236, 'logo_path': '/uV6QBPdn3MjQzAFdgEel6od7geg.png', 'name': 'Blinding Edge Pictures', 'origin_country': 'US'}, {'id': 5892, 'logo_path': '/fKJpBjX1Q39jChmSQAaSVw5VaB0.png', 'name': 'Buena Vista International', 'origin_country': 'US'}, {'id': 10338, 'logo_path': '/el2ap6lvjcEDdbyJoB3oKiYgXu9.png', 'name': 'Perfect World Pictures', 'origin_country': 'CN'}]
# [{'id': 2266, 'logo_path': '/owzVs2mguyyJ3vIn7EbgowpUPnk.png', 'name': 'Bold Films', 'origin_country': 'US'}, {'id': 3172, 'logo_path': '/kDedjRZwO8uyFhuHamomOhN6fzG.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}, {'id': 32157, 'logo_path': '/nBD7uzlUlpivUpOoUTg5UEZJoib.png', 'name': 'Right of Way Films', 'origin_country': 'US'}]
# [{'id': 79529, 'logo_path': '/gVN3k8emmKy4iV4KREWcCtxusZK.png', 'name': 'Torridon Films', 'origin_country': 'US'}, {'id': 101829, 'logo_path': '/8IOjCvgjq0zTrtP91cWD3kL2jMK.png', 'name': '16:14 Entertainment', 'origin_country': 'US'}, {'id': 1645, 'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png', 'name': 'Scott Free Productions', 'origin_country': 'GB'}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 1088, 'logo_path': '/9WOE5AQUXbOtLU6GTwfjS8OMF0v.png', 'name': 'Alcon Entertainment', 'origin_country': 'US'}, {'id': 78028, 'logo_path': '/sTFcDFfJaSVT3sv3DoaZDE4SlGB.png', 'name': 'Thunderbird Entertainment', 'origin_country': 'CA'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}]
# [{'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}, {'id': 7076, 'logo_path': '/8BFxn9NUWSgp0ndih569Gm62xiC.png', 'name': 'Chernin Entertainment', 'origin_country': 'US'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}, {'id': 138755, 'logo_path': None, 'name': 'Turnpike Films', 'origin_country': 'US'}]
# [{'id': 437, 'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png', 'name': 'Heyday Films', 'origin_country': 'GB'}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 30148, 'logo_path': '/zerhOenUD6CkH8SMgZUhrDkOs4w.png', 'name': 'Bona Film Group', 'origin_country': 'CN'}]
# [{'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}, {'id': 9015, 'logo_path': None, 'name': 'Worldview Entertainment', 'origin_country': ''}, {'id': 10104, 'logo_path': '/hNuGhsKVlmhnwSRcmOejDBDjh6w.png', 'name': 'New Regency Pictures', 'origin_country': 'US'}, {'id': 52660, 'logo_path': None, 'name': 'M Productions', 'origin_country': ''}, {'id': 47169, 'logo_path': None, 'name': 'Le Grisbi Productions', 'origin_country': 'US'}]
# [{'id': 11733, 'logo_path': None, 'name': 'Pariah', 'origin_country': ''}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 34, 'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png', 'name': 'Sony Pictures', 'origin_country': 'US'}]
# [{'id': 7505, 'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png', 'name': 'Marvel Entertainment', 'origin_country': 'US'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}, {'id': 28788, 'logo_path': None, 'name': 'Genre Films', 'origin_country': 'US'}, {'id': 431, 'logo_path': None, 'name': "The Donners' Company", 'origin_country': 'US'}]
# [{'id': 508, 'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png', 'name': 'Regency Enterprises', 'origin_country': 'US'}, {'id': 10104, 'logo_path': '/hNuGhsKVlmhnwSRcmOejDBDjh6w.png', 'name': 'New Regency Pictures', 'origin_country': 'US'}, {'id': 15829, 'logo_path': None, 'name': 'Pacific Standard', 'origin_country': ''}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}, {'id': 60682, 'logo_path': '/uyEGeoWO8xUtMIlEY8ztMZWizu6.png', 'name': 'Artemple - Hollywood', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}]
# [{'id': 10146, 'logo_path': '/xnFIOeq5cKw09kCWqV7foWDe4AA.png', 'name': 'Focus Features', 'origin_country': 'US'}, {'id': 11370, 'logo_path': None, 'name': 'Michael De Luca Productions', 'origin_country': 'US'}, {'id': 7626, 'logo_path': '/4839MGss4pPAalhqqYH1AD1CnEj.png', 'name': 'Trigger Street Productions', 'origin_country': 'US'}]
# [{'id': 41624, 'logo_path': '/wzKxIeQKlMP0y5CaAw25MD6EQmf.png', 'name': 'RatPac-Dune Entertainment', 'origin_country': 'US'}, {'id': 79, 'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png', 'name': 'Village Roadshow Pictures', 'origin_country': 'US'}, {'id': 6687, 'logo_path': None, 'name': 'Viz Media', 'origin_country': ''}, {'id': 787, 'logo_path': '/cCefBs1t7jxtiz3eCxBp9yxrxGx.png', 'name': '3 Arts Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}]
# [{'id': 41658, 'logo_path': None, 'name': 'Residaco', 'origin_country': ''}, {'id': 14, 'logo_path': '/m6AHu84oZQxvq7n1rsvMNJIAsMu.png', 'name': 'Miramax', 'origin_country': 'US'}, {'id': 10807, 'logo_path': '/j0BcMaJKIiDDYHq9lriTcM0Npka.png', 'name': 'Troublemaker Studios', 'origin_country': 'US'}, {'id': 11006, 'logo_path': None, 'name': 'Aldamisa Entertainment', 'origin_country': ''}, {'id': 13241, 'logo_path': None, 'name': 'Demarest Films', 'origin_country': ''}, {'id': 29076, 'logo_path': None, 'name': 'Solipsist Film', 'origin_country': ''}, {'id': 11005, 'logo_path': None, 'name': 'AR Films', 'origin_country': ''}]
# [{'id': 12, 'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png', 'name': 'New Line Cinema', 'origin_country': 'US'}, {'id': 11, 'logo_path': '/6FAuASQHybRkZUk08p9PzSs9ezM.png', 'name': 'WingNut Films', 'origin_country': 'NZ'}, {'id': 5237, 'logo_path': None, 'name': 'The Saul Zaentz Company', 'origin_country': 'US'}]
# [{'id': 84409, 'logo_path': None, 'name': 'Wayfarer Entertainment', 'origin_country': 'US'}, {'id': 5490, 'logo_path': '/xuJSR4dWsvkE194aemIJwflyNF2.png', 'name': 'CBS Films', 'origin_country': 'US'}]
# [{'id': 2348, 'logo_path': '/m31fQvZJuUvAgxoqTiCGYFBfZYe.png', 'name': 'Nickelodeon Movies', 'origin_country': 'US'}, {'id': 4, 'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png', 'name': 'Paramount', 'origin_country': 'US'}, {'id': 2481, 'logo_path': '/nVEP2IHCDOBOldgDL4SSufitN9.png', 'name': 'Platinum Dunes', 'origin_country': 'US'}]
# [{'id': 11073, 'logo_path': '/wHs44fktdoj6c378ZbSWfzKsM2Z.png', 'name': 'Sony Pictures Television', 'origin_country': 'US'}, {'id': 2605, 'logo_path': None, 'name': 'Gran Via Productions', 'origin_country': 'US'}, {'id': 33742, 'logo_path': None, 'name': 'High Bridge Entertainment', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 4, 'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png', 'name': 'Paramount', 'origin_country': 'US'}]
# [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png', 'name': 'Legendary Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 83645, 'logo_path': None, 'name': 'Huahua Media', 'origin_country': 'CN'}, {'id': 882, 'logo_path': '/fRSWWjquvzcHjACbtF53utZFIll.png', 'name': 'Toho Company, Ltd.', 'origin_country': 'JP'}]
# [{'id': 28787, 'logo_path': None, 'name': 'WideAwake', 'origin_country': ''}, {'id': 28788, 'logo_path': None, 'name': 'Genre Films', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}]
# [{'id': 9996, 'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png', 'name': 'Syncopy', 'origin_country': 'GB'}, {'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png', 'name': 'Legendary Entertainment', 'origin_country': 'US'}, {'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}]
# [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 436, 'logo_path': '/A7WCkG3F0NFvjGCwUnclpGdIu9E.png', 'name': '1492 Pictures', 'origin_country': 'US'}, {'id': 437, 'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png', 'name': 'Heyday Films', 'origin_country': 'GB'}]
# [{'id': 7505, 'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png', 'name': 'Marvel Entertainment', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}, {'id': 112049, 'logo_path': None, 'name': 'Kinberg Genre', 'origin_country': ''}, {'id': 104228, 'logo_path': None, 'name': 'Maximum Effort', 'origin_country': 'US'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}]
# [{'id': 25998, 'logo_path': None, 'name': 'Chris Morgan Productions', 'origin_country': 'US'}, {'id': 73669, 'logo_path': '/usfW3lL4cL8eatNAlhfRrryyKkK.png', 'name': 'Seven Bucks Productions', 'origin_country': 'US'}, {'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}]
# [{'id': 1632, 'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png', 'name': 'Lionsgate', 'origin_country': 'US'}, {'id': 5420, 'logo_path': '/dlW4Kh5dNieKNURnymsu57y6fMf.png', 'name': 'Color Force', 'origin_country': 'US'}]
# [{'id': 10104, 'logo_path': '/hNuGhsKVlmhnwSRcmOejDBDjh6w.png', 'name': 'New Regency Pictures', 'origin_country': 'US'}, {'id': 508, 'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png', 'name': 'Regency Enterprises', 'origin_country': 'US'}, {'id': 100784, 'logo_path': None, 'name': 'Lucky Strike Film Studios', 'origin_country': ''}]
# [{'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 8881, 'logo_path': None, 'name': 'Zak Productions', 'origin_country': ''}, {'id': 41624, 'logo_path': '/wzKxIeQKlMP0y5CaAw25MD6EQmf.png', 'name': 'RatPac-Dune Entertainment', 'origin_country': 'US'}, {'id': 507, 'logo_path': '/z7H707qUWigbjHnJDMfj6QITEpb.png', 'name': 'Atlas Entertainment', 'origin_country': 'US'}, {'id': 9995, 'logo_path': '/mAIGhOYhN4N2N0F7p4dbKhgXf3l.png', 'name': 'Cruel & Unusual Films', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}]
# [{'id': 82819, 'logo_path': '/5Z8WWr0Lf1tInVWwJsxPP0uMz9a.png', 'name': 'Skydance Media', 'origin_country': 'US'}, {'id': 130, 'logo_path': '/c9dVHPOL3cqCr2593Ahk0nEKTEM.png', 'name': 'Jerry Bruckheimer Films', 'origin_country': 'US'}, {'id': 69484, 'logo_path': '/2xtmvbEse87LM7OJXVksv7DToZx.png', 'name': 'Alibaba Pictures Group', 'origin_country': 'CN'}, {'id': 102774, 'logo_path': None, 'name': 'Fosun Group Forever Pictures', 'origin_country': ''}]
# [{'id': 10342, 'logo_path': '/eS79pslnoKbWg7t3PMA9ayl0bGs.png', 'name': 'Studio Ghibli', 'origin_country': 'JP'}]
# [{'id': 3756, 'logo_path': '/dH51ZYZnD7ezWMqZCItuvATr2j8.png', 'name': 'CoMix Wave Films', 'origin_country': 'JP'}]
# [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 12026, 'logo_path': None, 'name': 'Gold Circle Films', 'origin_country': 'US'}, {'id': 12365, 'logo_path': None, 'name': 'Brownstone Productions', 'origin_country': 'US'}]
# [{'id': 1634, 'logo_path': None, 'name': 'Truenorth Productions', 'origin_country': 'IS'}, {'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZcyE8pDb.png', 'name': 'Lucasfilm Ltd.', 'origin_country': 'US'}, {'id': 11461, 'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png', 'name': 'Bad Robot', 'origin_country': 'US'}]
# [{'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 128064, 'logo_path': None, 'name': 'DC Films', 'origin_country': 'US'}, {'id': 444, 'logo_path': '/42UPdZl6B2cFXgNUASR8hSt9mpS.png', 'name': 'Dune Entertainment', 'origin_country': 'US'}, {'id': 507, 'logo_path': '/z7H707qUWigbjHnJDMfj6QITEpb.png', 'name': 'Atlas Entertainment', 'origin_country': 'US'}, {'id': 9995, 'logo_path': '/mAIGhOYhN4N2N0F7p4dbKhgXf3l.png', 'name': 'Cruel & Unusual Films', 'origin_country': 'US'}, {'id': 81620, 'logo_path': '/gNp4dfuBOXmVWdGKb63NfbFNbFi.png', 'name': 'Tencent Pictures', 'origin_country': 'CN'}, {'id': 83838, 'logo_path': None, 'name': 'Wanda Pictures', 'origin_country': 'CN'}]
# [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png', 'name': 'Pixar', 'origin_country': 'US'}]
# [{'id': 11391, 'logo_path': None, 'name': 'Tribeca Productions', 'origin_country': 'US'}, {'id': 23243, 'logo_path': None, 'name': 'Sikelia Productions', 'origin_country': 'US'}, {'id': 8880, 'logo_path': '/fE7LBw7Jz8R29EABFGCvWNriZxN.png', 'name': 'Winkler Films', 'origin_country': 'US'}]
# [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4HuilrcV0yujsZ9.png', 'name': 'Walt Disney Animation Studios', 'origin_country': 'US'}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}]
# [{'id': 491, 'logo_path': '/rUp0lLKa1pr4UsPm8fgzmnNGxtq.png', 'name': 'Summit Entertainment', 'origin_country': 'US'}, {'id': 33681, 'logo_path': '/dHx2nsV9AC7IBlKN2dk1FDImvOz.png', 'name': 'Black Label Media', 'origin_country': 'US'}, {'id': 10161, 'logo_path': None, 'name': 'Gilbert Films', 'origin_country': 'US'}, {'id': 53247, 'logo_path': None, 'name': 'Impostor Pictures', 'origin_country': 'US'}, {'id': 2527, 'logo_path': '/osO7TGmlRMistSQ5JZusPhbKUHk.png', 'name': 'Marc Platt Productions', 'origin_country': 'US'}]
# [{'id': 10807, 'logo_path': '/j0BcMaJKIiDDYHq9lriTcM0Npka.png', 'name': 'Troublemaker Studios', 'origin_country': 'US'}, {'id': 574, 'logo_path': '/iB6GjNVHs5hOqcEYt2rcjBqIjki.png', 'name': 'Lightstorm Entertainment', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}]
# [{'id': 2376, 'logo_path': '/yeNoWmSHZfvKsBYuL8uTRE4LPdQ.png', 'name': 'Blueprint Pictures', 'origin_country': 'GB'}, {'id': 94694, 'logo_path': '/NVim8F3S69VMWLEXvsFUODDy9V.png', 'name': 'Cutting Edge Group', 'origin_country': 'US'}, {'id': 43, 'logo_path': '/4RgIPr55kBakgupWkzdDxqXJEqr.png', 'name': 'Fox Searchlight Pictures', 'origin_country': 'US'}, {'id': 6705, 'logo_path': '/e8EXNSfwr5E9d3TR8dHKbQnQK4W.png', 'name': 'Film4 Productions', 'origin_country': 'GB'}]
# [{'id': 39407, 'logo_path': '/1ht2ayBUdGgKuLRCkTjyGVEY5VL.png', 'name': 'B-Reel Films', 'origin_country': 'SE'}, {'id': 123620, 'logo_path': None, 'name': 'Square Peg', 'origin_country': 'US'}]
# [{'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 12, 'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png', 'name': 'New Line Cinema', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 11565, 'logo_path': None, 'name': 'The Safran Company', 'origin_country': 'US'}, {'id': 73669, 'logo_path': '/usfW3lL4cL8eatNAlhfRrryyKkK.png', 'name': 'Seven Bucks Productions', 'origin_country': 'US'}, {'id': 128064, 'logo_path': None, 'name': 'DC Films', 'origin_country': 'US'}]
# [{'id': 79, 'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png', 'name': 'Village Roadshow Pictures', 'origin_country': 'US'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 1163, 'logo_path': None, 'name': 'Larger Than Life Productions', 'origin_country': 'US'}, {'id': 104907, 'logo_path': None, 'name': 'Rahway Road Productions', 'origin_country': 'US'}, {'id': 1782, 'logo_path': '/d1mlUfuG0NoQ4x0C7bK80wLGWA1.png', 'name': 'Smoke House Pictures', 'origin_country': 'US'}]
# [{'id': 12, 'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png', 'name': 'New Line Cinema', 'origin_country': 'US'}, {'id': 11, 'logo_path': '/6FAuASQHybRkZUk08p9PzSs9ezM.png', 'name': 'WingNut Films', 'origin_country': 'NZ'}, {'id': 5237, 'logo_path': None, 'name': 'The Saul Zaentz Company', 'origin_country': 'US'}]
# [{'id': 48738, 'logo_path': None, 'name': 'Campbell Grobman Films', 'origin_country': 'US'}, {'id': 71488, 'logo_path': None, 'name': 'Eclectic Pictures', 'origin_country': 'US'}, {'id': 103331, 'logo_path': None, 'name': 'G-BASE', 'origin_country': 'US'}, {'id': 1020, 'logo_path': '/kuUIHNwMec4dwOLghDhhZJzHZTd.png', 'name': 'Millennium Films', 'origin_country': 'US'}]
# [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}]
# [{'id': 6896, 'logo_path': '/2Q89KvzxTKB5BAv9RqFIPI1qb7E.png', 'name': 'EuropaCorp', 'origin_country': 'FR'}, {'id': 1115, 'logo_path': '/ntH7T5gsN6wtyrfHGHJDTuneQ7o.png', 'name': 'M6 Films', 'origin_country': 'FR'}, {'id': 6877, 'logo_path': None, 'name': 'Grive Productions', 'origin_country': ''}, {'id': 10611, 'logo_path': '/zQ4fGaEnNkWfSzyygXRcUZwPmDG.png', 'name': 'Ciné+', 'origin_country': 'FR'}, {'id': 11261, 'logo_path': '/g7p4vSwqsIo6zYptyN3hoDxFp7y.png', 'name': 'M6', 'origin_country': 'FR'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}, {'id': 87854, 'logo_path': None, 'name': 'Taken 3', 'origin_country': ''}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}, {'id': 104, 'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png', 'name': 'Canal+', 'origin_country': 'FR'}]
# [{'id': 2108, 'logo_path': None, 'name': 'Battleplan Productions', 'origin_country': 'US'}, {'id': 59663, 'logo_path': None, 'name': 'Compadre Entertainment', 'origin_country': ''}, {'id': 72810, 'logo_path': '/vmGhorQd0J9p8SJagDJM3ZpYWN6.png', 'name': 'Paradox Studios', 'origin_country': 'US'}, {'id': 59593, 'logo_path': None, 'name': 'AMBI Group', 'origin_country': 'US'}]
# [{'id': 22826, 'logo_path': '/37ZxE1qShQ44VdsRPkO1zOtnMKi.png', 'name': 'Hasbro Studios', 'origin_country': 'US'}, {'id': 4, 'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png', 'name': 'Paramount', 'origin_country': 'US'}, {'id': 435, 'logo_path': '/AjzK0s2w1GtLfR4hqCjVSYi0Sr8.png', 'name': 'Di Bonaventura Pictures', 'origin_country': 'US'}]
# [{'id': 3657, 'logo_path': '/2YXnZa6yPjxdHKzBLgmf57D8QpM.png', 'name': 'Sidus', 'origin_country': 'KR'}, {'id': 20064, 'logo_path': '/6HvsksiEE7DknfZU5HT1mUs563q.png', 'name': 'Next Entertainment World', 'origin_country': 'KR'}, {'id': 121669, 'logo_path': None, 'name': 'Locus Creative Studios', 'origin_country': ''}]
# [{'id': 11068, 'logo_path': '/jOdUllzDZRFy0tPIFDEwpP4Mpv4.png', 'name': 'Nostromo Pictures', 'origin_country': 'ES'}, {'id': 12292, 'logo_path': '/llGRXF5WYUW2fzXg0ebCoKMXjmT.png', 'name': 'Temple Hill Entertainment', 'origin_country': 'US'}, {'id': 127127, 'logo_path': None, 'name': 'Marc Graue Recording Studios', 'origin_country': ''}]
# [{'id': 9195, 'logo_path': '/ou5BUbtulr6tIt699q6xJiEQTR9.png', 'name': 'Touchstone Pictures', 'origin_country': 'US'}, {'id': 9996, 'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png', 'name': 'Syncopy', 'origin_country': 'GB'}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}]
# [{'id': 3281, 'logo_path': '/8tMybAieh64uzvm8knSjXOFX8Qc.png', 'name': 'GK Films', 'origin_country': 'GB'}, {'id': 508, 'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png', 'name': 'Regency Enterprises', 'origin_country': 'US'}, {'id': 90995, 'logo_path': None, 'name': 'Queen Films', 'origin_country': 'GB'}, {'id': 11391, 'logo_path': None, 'name': 'Tribeca Productions', 'origin_country': 'US'}, {'id': 10104, 'logo_path': '/hNuGhsKVlmhnwSRcmOejDBDjh6w.png', 'name': 'New Regency Pictures', 'origin_country': 'US'}, {'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png', 'name': '20th Century Fox', 'origin_country': 'US'}]
# [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png', 'name': 'Legendary Entertainment', 'origin_country': 'US'}, {'id': 101082, 'logo_path': None, 'name': 'Double Dare You Productions', 'origin_country': 'US'}, {'id': 104742, 'logo_path': None, 'name': 'UpperRoom Productions', 'origin_country': ''}, {'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 1778, 'logo_path': '/69xm6sF3JxugGVjfZfm1YY6d7EE.png', 'name': 'DENTSU', 'origin_country': 'JP'}, {'id': 107182, 'logo_path': None, 'name': 'Clear Angle Studios', 'origin_country': ''}, {'id': 107183, 'logo_path': None, 'name': 'Double Negative (DNEG)', 'origin_country': ''}, {'id': 3341, 'logo_path': '/dTG5dXE1kU2mpmL9BNnraffckLU.png', 'name': 'Fuji Television Network', 'origin_country': 'JP'}, {'id': 10338, 'logo_path': '/el2ap6lvjcEDdbyJoB3oKiYgXu9.png', 'name': 'Perfect World Pictures', 'origin_country': 'CN'}, {'id': 101832, 'logo_path': '/vO7CKIeogFxphT1CHkUIhjEXf2C.png', 'name': 'Twisted Media', 'origin_country': 'US'}]
# [{'id': 429, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Comics', 'origin_country': 'US'}, {'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png', 'name': 'Legendary Entertainment', 'origin_country': 'US'}, {'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp1kYT3izLS5.png', 'name': 'DC Entertainment', 'origin_country': 'US'}, {'id': 9996, 'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png', 'name': 'Syncopy', 'origin_country': 'GB'}, {'id': 19231, 'logo_path': None, 'name': 'Patalex III Productions Limited', 'origin_country': ''}, {'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}]
# [{'id': 106544, 'logo_path': None, 'name': 'AGBO', 'origin_country': 'US'}, {'id': 36209, 'logo_path': '/doQEl9S1rg0l0NEtpkxf0N46OHQ.png', 'name': 'MWM Studios', 'origin_country': 'US'}, {'id': 3393, 'logo_path': None, 'name': 'Huayi Brothers', 'origin_country': 'HK'}]
# ...
# [{'id': 38764, 'logo_path': None, 'name': 'Banner Entertainment', 'origin_country': ''}, {'id': 105850, 'logo_path': None, 'name': 'Meanwhile Films', 'origin_country': ''}]
# [{'id': 85588, 'logo_path': None, 'name': 'Quexito Films', 'origin_country': ''}, {'id': 1182, 'logo_path': '/bkgwJWvqqLuzsXV2Qv3Mg3wfcNZ.png', 'name': 'Telecinco Cinema', 'origin_country': 'ES'}]
# [{'id': 97854, 'logo_path': None, 'name': 'National CineMedia', 'origin_country': ''}, {'id': 21959, 'logo_path': '/e6TWATLzn5bLouGIdQFLYL07Ude.png', 'name': 'Angels & Airwaves', 'origin_country': 'US'}, {'id': 77902, 'logo_path': None, 'name': 'Company 3', 'origin_country': ''}, {'id': 97850, 'logo_path': None, 'name': 'New Dog Media', 'origin_country': ''}, {'id': 97851, 'logo_path': None, 'name': 'Griffin Interplanetary Studios', 'origin_country': 'CA'}, {'id': 97852, 'logo_path': None, 'name': 'Five VFX', 'origin_country': ''}, {'id': 97853, 'logo_path': '/4eG0WVk8h8kcOhdnAJNJ3F31MX9.png', 'name': 'Zoic Studios', 'origin_country': ''}]
# [{'id': 1475, 'logo_path': None, 'name': 'UGC Images', 'origin_country': ''}]
# []
# [{'id': 694, 'logo_path': '/5LEHONGkZBIoWvp1ygHOF8iyi1M.png', 'name': 'StudioCanal', 'origin_country': 'FR'}, {'id': 10163, 'logo_path': '/16KWBMmfPX0aJzDExDrPxSLj0Pg.png', 'name': 'Working Title Films', 'origin_country': 'GB'}]
# []
# [{'id': 1926, 'logo_path': '/sORCydQs61kwWqRIIzPiBpgVVag.png', 'name': 'Les Films du Fleuve', 'origin_country': 'BE'}, {'id': 11796, 'logo_path': '/tx6LOQcTSqgW8ffKxovuJHjlYVw.png', 'name': "Centre du Cinéma et de l'Audiovisuel de la Fédération Wallonie-Bruxelles", 'origin_country': 'BE'}]
# [{'id': 5716, 'logo_path': None, 'name': 'Polygon Entertainment', 'origin_country': ''}, {'id': 7036, 'logo_path': '/javbyY0ZCvlFJtly3tpZqf2NwLX.png', 'name': 'CJ Entertainment', 'origin_country': 'KR'}, {'id': 10955, 'logo_path': None, 'name': 'JK Film', 'origin_country': 'KR'}]
# [{'id': 23123, 'logo_path': '/cEqVIluQuO1ubtID8RvOem4ZiIg.png', 'name': 'Mars Film', 'origin_country': 'FR'}, {'id': 83, 'logo_path': '/9OQ0rm55xtlgX7KcAKMUePJSrQc.png', 'name': 'France 2 Cinéma', 'origin_country': 'FR'}, {'id': 57752, 'logo_path': '/2k3j1B8TEbZPQgckP6zh75pIb4s.png', 'name': 'Nord-Ouest Films', 'origin_country': 'FR'}, {'id': 123323, 'logo_path': None, 'name': 'Jobi', 'origin_country': ''}]
# [{'id': 29566, 'logo_path': '/wHbtRtUnXGNzX0riQIpq1fcgueq.png', 'name': 'Atresmedia', 'origin_country': 'ES'}, {'id': 7847, 'logo_path': None, 'name': 'Escándalo Films', 'origin_country': ''}, {'id': 8111, 'logo_path': None, 'name': 'Apaches Entertainment', 'origin_country': ''}, {'id': 8193, 'logo_path': '/3DzaUV9bMcQ9wOocHbO5qIwOLRx.png', 'name': 'ZircoZine', 'origin_country': 'ES'}]
# [{'id': 3172, 'logo_path': '/kDedjRZwO8uyFhuHamomOhN6fzG.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}]
# [{'id': 1311, 'logo_path': '/ic2bTizdzRLDVzAvN7MXdUg3WQV.png', 'name': 'The Asylum', 'origin_country': 'US'}]
# [{'id': 3140, 'logo_path': None, 'name': 'Pacific Entertainment Group', 'origin_country': ''}]
# [{'id': 43, 'logo_path': '/4RgIPr55kBakgupWkzdDxqXJEqr.png', 'name': 'Fox Searchlight Pictures', 'origin_country': 'US'}, {'id': 52896, 'logo_path': None, 'name': 'Choke Film', 'origin_country': ''}, {'id': 6332, 'logo_path': '/42UPdZl6B2cFXgNUASR8hSt9mpS.png', 'name': 'Dune Entertainment III', 'origin_country': 'US'}, {'id': 3272, 'logo_path': None, 'name': 'Aramid Entertainment Fund', 'origin_country': ''}, {'id': 1836, 'logo_path': None, 'name': 'Contrafilm', 'origin_country': ''}, {'id': 1962, 'logo_path': None, 'name': 'ATO Pictures', 'origin_country': ''}]
# []
# [{'id': 37627, 'logo_path': None, 'name': 'Fubar Films FL', 'origin_country': ''}, {'id': 93567, 'logo_path': None, 'name': 'Fubar Films', 'origin_country': ''}, {'id': 10039, 'logo_path': '/b8w4LldQolMKiLZw4FQJBcXSDGI.png', 'name': 'Anonymous Content', 'origin_country': 'US'}]
# []
# [{'id': 3172, 'logo_path': '/kDedjRZwO8uyFhuHamomOhN6fzG.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}, {'id': 1974, 'logo_path': None, 'name': 'Duplass Brothers Productions', 'origin_country': 'US'}]
# [{'id': 1218, 'logo_path': None, 'name': 'The Film Consortium', 'origin_country': ''}, {'id': 2452, 'logo_path': '/6CLoZ59fLPG7UyxQtGTqRevjf58.png', 'name': 'UK Film Council', 'origin_country': 'GB'}, {'id': 29018, 'logo_path': None, 'name': 'Visionview Production', 'origin_country': ''}, {'id': 99272, 'logo_path': '/xt9cawh63M0bkKrc0VvDtZ8q2sa.png', 'name': 'Icon Films', 'origin_country': 'GB'}, {'id': 163, 'logo_path': None, 'name': 'Revolution Films', 'origin_country': 'GB'}, {'id': 135268, 'logo_path': None, 'name': 'Doubting Hall Limited', 'origin_country': ''}]
# [{'id': 44973, 'logo_path': None, 'name': 'Badhouse Studios Mexico', 'origin_country': ''}, {'id': 16631, 'logo_path': None, 'name': 'Project One Films', 'origin_country': ''}]
# [{'id': 78799, 'logo_path': None, 'name': 'black & white pictures', 'origin_country': ''}, {'id': 78800, 'logo_path': None, 'name': 'tony montana films', 'origin_country': ''}, {'id': 55783, 'logo_path': None, 'name': 'Ether Films', 'origin_country': ''}, {'id': 58588, 'logo_path': None, 'name': 'Ronnoco Productions', 'origin_country': ''}]
# [{'id': 2683, 'logo_path': '/mOL2WcHtox2urbUf1oJvjw7kz01.png', 'name': 'Rai Cinema', 'origin_country': 'IT'}, {'id': 18156, 'logo_path': '/3nAuYcaWdpW0ULMvMz6V5HIJmCO.png', 'name': 'Indiana Production Company', 'origin_country': 'IT'}, {'id': 18973, 'logo_path': '/lM081nCPhuKIPc2lJWstsQAlIaJ.png', 'name': '01 Distribution', 'origin_country': 'IT'}]
# [{'id': 29366, 'logo_path': None, 'name': 'Channel 83 Films', 'origin_country': ''}]
# [{'id': 78716, 'logo_path': None, 'name': 'Vermilon Films', 'origin_country': 'US'}]
# [{'id': 726, 'logo_path': '/hHaQQgxqg2NohqZSxbMTB9E483m.png', 'name': 'Haut et Court', 'origin_country': 'FR'}]
# [{'id': 21899, 'logo_path': None, 'name': 'Michael Mailer Films', 'origin_country': ''}, {'id': 22498, 'logo_path': None, 'name': 'Black Sand Pictures', 'origin_country': 'US'}]
# [{'id': 81187, 'logo_path': None, 'name': 'Best FX Adelaide', 'origin_country': ''}, {'id': 7337, 'logo_path': None, 'name': 'Mushroom Pictures', 'origin_country': 'AU'}]
# []
# []
# [{'id': 12987, 'logo_path': None, 'name': 'Filmmaker R&K', 'origin_country': 'KR'}, {'id': 7036, 'logo_path': '/javbyY0ZCvlFJtly3tpZqf2NwLX.png', 'name': 'CJ Entertainment', 'origin_country': 'KR'}, {'id': 112927, 'logo_path': None, 'name': 'filmK', 'origin_country': 'KR'}]
# [{'id': 19159, 'logo_path': None, 'name': 'Vito Films', 'origin_country': ''}, {'id': 356, 'logo_path': '/9tW5wZEGotn1Ei5pErA88m47XiD.png', 'name': 'TF1 Films Production', 'origin_country': 'FR'}]
# [{'id': 11073, 'logo_path': '/wHs44fktdoj6c378ZbSWfzKsM2Z.png', 'name': 'Sony Pictures Television', 'origin_country': 'US'}]
# [{'id': 321, 'logo_path': '/pfp6VWF3tYfOHHVRHpYe2iGcYrf.png', 'name': 'Memfis Film', 'origin_country': 'SE'}, {'id': 76, 'logo_path': None, 'name': 'Zentropa Entertainments', 'origin_country': 'DK'}, {'id': 2801, 'logo_path': '/bswb1PLLsKDUXMLgy42bZtCtIde.png', 'name': 'Film i Väst', 'origin_country': 'SE'}, {'id': 2999, 'logo_path': '/zGSqFee9aDgDuLD6vcs2mcJUem4.png', 'name': 'SVT', 'origin_country': 'SE'}, {'id': 253, 'logo_path': None, 'name': 'Keyfilms Roma', 'origin_country': 'IT'}, {'id': 5403, 'logo_path': '/fAz2WhTpoMxutBA92JqlfeHEGuz.png', 'name': 'Nordisk Film & TV Fond', 'origin_country': 'NO'}]
# [{'id': 75579, 'logo_path': None, 'name': 'Cave Pictures', 'origin_country': ''}, {'id': 10290, 'logo_path': '/imFSHWEIgpk3YjqIMxafZ6BYT9H.png', 'name': 'BCDF Pictures', 'origin_country': 'US'}, {'id': 79500, 'logo_path': None, 'name': 'Blackbird', 'origin_country': 'US'}]
# [{'id': 779, 'logo_path': '/KFFOFoztyjV5epvnW5GerPbcvx.png', 'name': 'Lucky Red', 'origin_country': 'IT'}]
# [{'id': 13318, 'logo_path': None, 'name': 'Récifilms', 'origin_country': ''}]
# [{'id': 3477, 'logo_path': None, 'name': 'Star Overseas', 'origin_country': ''}]
# [{'id': 6355, 'logo_path': None, 'name': 'Silverstar Limited', 'origin_country': ''}, {'id': 3282, 'logo_path': None, 'name': 'Larry Levinson Productions', 'origin_country': 'US'}]
# [{'id': 27912, 'logo_path': None, 'name': 'Indie Entertainment', 'origin_country': ''}, {'id': 87458, 'logo_path': None, 'name': 'Salem Street Entertainment', 'origin_country': 'US'}]
# [{'id': 95260, 'logo_path': None, 'name': 'Strophic Productions Limited', 'origin_country': ''}]
# [{'id': 955, 'logo_path': '/5xnXD3PJI1HqOJceSAKZ3fDqO1V.png', 'name': 'Nikkatsu Corporation', 'origin_country': 'JP'}]
# [{'id': 7353, 'logo_path': '/yV5sxmYy4nBptmedJbsUKpr6W4M.png', 'name': 'Gateway Films', 'origin_country': ''}]
# [{'id': 794, 'logo_path': None, 'name': 'Agi Orsi Productions', 'origin_country': 'US'}, {'id': 93985, 'logo_path': None, 'name': 'Vans (US)', 'origin_country': ''}]
# [{'id': 50963, 'logo_path': None, 'name': 'Philippe Martinez Productions', 'origin_country': ''}, {'id': 13792, 'logo_path': None, 'name': 'Perpetual Media Capital', 'origin_country': ''}, {'id': 16936, 'logo_path': None, 'name': 'Arramis Films', 'origin_country': ''}, {'id': 34788, 'logo_path': None, 'name': 'Alchemedia Films', 'origin_country': ''}, {'id': 6626, 'logo_path': '/A1BnMoWjzjOrjzpWimyBQkf84mS.png', 'name': 'Voltage Pictures', 'origin_country': 'US'}]
# [{'id': 1107, 'logo_path': None, 'name': 'Seven Pictures', 'origin_country': ''}, {'id': 7930, 'logo_path': None, 'name': 'Olga Film GmbH', 'origin_country': ''}, {'id': 47, 'logo_path': '/i7Z9ot2o3N5Sa3HrF09kniFs2y8.png', 'name': 'Constantin Film', 'origin_country': 'DE'}]
# [{'id': 12096, 'logo_path': None, 'name': 'Mandarin Films', 'origin_country': 'CN'}]
# [{'id': 58399, 'logo_path': None, 'name': 'Pantelion Films', 'origin_country': ''}]
# [{'id': 42613, 'logo_path': None, 'name': 'Little Dragon Productions', 'origin_country': ''}]
# [{'id': 50804, 'logo_path': None, 'name': 'Nordsvensk Filmunderhållning', 'origin_country': 'SE'}, {'id': 12925, 'logo_path': None, 'name': 'The Walt Disney Company Nordic', 'origin_country': 'SE'}, {'id': 25297, 'logo_path': '/eBEOs6T0nVa8RKWmZbBWIvc4daL.png', 'name': 'FLX', 'origin_country': 'SE'}, {'id': 28005, 'logo_path': '/eaHxuuLNWXArn3mHkj0vdTfBgI4.png', 'name': 'Nice Drama', 'origin_country': 'SE'}, {'id': 28004, 'logo_path': None, 'name': 'Nice FLX Pictures', 'origin_country': 'SE'}, {'id': 2801, 'logo_path': '/bswb1PLLsKDUXMLgy42bZtCtIde.png', 'name': 'Film i Väst', 'origin_country': 'SE'}, {'id': 2802, 'logo_path': '/x3cLK4hmrDxBeoD7eWbfJL2dGxP.png', 'name': 'TV4', 'origin_country': 'SE'}]
# [{'id': 288, 'logo_path': '/wdmwQuV4R1MIr8A78izZkC184uC.png', 'name': 'BBC Films', 'origin_country': 'GB'}, {'id': 866, 'logo_path': None, 'name': 'Pathé Renn Productions', 'origin_country': 'FR'}, {'id': 2452, 'logo_path': '/6CLoZ59fLPG7UyxQtGTqRevjf58.png', 'name': 'UK Film Council', 'origin_country': 'GB'}, {'id': 7584, 'logo_path': '/eGkfvvyf4fJTvBUR1xt1669IPA3.png', 'name': 'Screen Australia', 'origin_country': 'AU'}, {'id': 26716, 'logo_path': None, 'name': 'Hopscotch Productions', 'origin_country': 'AU'}, {'id': 26717, 'logo_path': None, 'name': 'Jan Chapman Pictures', 'origin_country': ''}, {'id': 1380, 'logo_path': None, 'name': 'Australian Film Finance Corporation', 'origin_country': 'AU'}]
# [{'id': 1063, 'logo_path': '/fpVBhNnopOZwGuF0gg99oBHp1ht.png', 'name': 'Brightlight Pictures', 'origin_country': 'CA'}]
# [{'id': 3158, 'logo_path': None, 'name': 'Katakuri-ke no Kôfuku Seisaku Iinkai', 'origin_country': ''}, {'id': 192, 'logo_path': '/93eAKlnQecDdMtucfOprzcjMw9V.png', 'name': 'Shochiku Co., Ltd.', 'origin_country': 'JP'}]
# [{'id': 122903, 'logo_path': None, 'name': 'Art & Industry', 'origin_country': 'US'}]
# [{'id': 3244, 'logo_path': None, 'name': 'Media Pro Pictures', 'origin_country': 'RO'}]
# [{'id': 15073, 'logo_path': None, 'name': 'Enlightenment Productions', 'origin_country': ''}, {'id': 67263, 'logo_path': None, 'name': 'Falling Snow', 'origin_country': ''}, {'id': 67264, 'logo_path': None, 'name': 'SK Enlightenment', 'origin_country': ''}]
# [{'id': 10989, 'logo_path': None, 'name': 'Muskat Filmed Properties', 'origin_country': 'US'}, {'id': 12650, 'logo_path': '/nGzVgMmnnaArZG3Dw1Qxmke37vH.png', 'name': 'Dogfish Pictures', 'origin_country': 'US'}]
# [{'id': 2248, 'logo_path': None, 'name': 'A-Mark Entertainment', 'origin_country': ''}]
# [{'id': 11370, 'logo_path': None, 'name': 'Michael De Luca Productions', 'origin_country': 'US'}, {'id': 23365, 'logo_path': None, 'name': 'Vandalia Films', 'origin_country': ''}]
# [{'id': 1159, 'logo_path': None, 'name': 'Argyll Film Partners', 'origin_country': ''}, {'id': 1160, 'logo_path': None, 'name': 'Gummshoe Productions', 'origin_country': ''}, {'id': 1161, 'logo_path': None, 'name': 'Integrity Partners', 'origin_country': ''}, {'id': 1162, 'logo_path': None, 'name': 'Pray For Rain Pictures', 'origin_country': 'US'}]
# []
# [{'id': 111715, 'logo_path': None, 'name': 'Tiger Pictures', 'origin_country': 'KR'}, {'id': 3491, 'logo_path': '/hXRKXi3M9qfP4Npi1kjAaH4eGnM.png', 'name': 'Showbox', 'origin_country': 'KR'}]
# []
# []
# [{'id': 124957, 'logo_path': None, 'name': 'Deeble & Stone', 'origin_country': ''}, {'id': 14801, 'logo_path': '/bnlD5KJ5oSzBYbEpDkwi6w8SoBO.png', 'name': 'Apple', 'origin_country': 'US'}]
# [{'id': 46315, 'logo_path': '/hnLZ2bfiSnZQktbPJPr0I55iP2n.png', 'name': 'Wizart Animation', 'origin_country': 'RU'}, {'id': 318, 'logo_path': '/q0UG4oZERwIywJdDPF4lRlvdYGW.png', 'name': 'CTB Film Company', 'origin_country': 'RU'}]
# [{'id': 12142, 'logo_path': '/rPnEeMwxjI6rYMGqkWqIWwIJXxi.png', 'name': 'XYZ Films', 'origin_country': 'US'}, {'id': 7625, 'logo_path': '/kzq4ibnNeZrp00zpBWv3st1QCOh.png', 'name': 'Automatik Entertainment', 'origin_country': 'US'}, {'id': 85465, 'logo_path': None, 'name': 'Oddfellows Entertainment', 'origin_country': 'CA'}, {'id': 90760, 'logo_path': None, 'name': 'Exhibit Entertainment', 'origin_country': 'US'}]
# [{'id': 10426, 'logo_path': None, 'name': 'Panay Films', 'origin_country': ''}, {'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}]
# [{'id': 3312, 'logo_path': None, 'name': 'Martini Films', 'origin_country': ''}]
# [{'id': 1267, 'logo_path': '/j3kXC0bEn4vxrIyUApeKBtSUu9w.png', 'name': 'Ecosse Films', 'origin_country': 'GB'}, {'id': 2452, 'logo_path': '/6CLoZ59fLPG7UyxQtGTqRevjf58.png', 'name': 'UK Film Council', 'origin_country': 'GB'}, {'id': 6705, 'logo_path': '/e8EXNSfwr5E9d3TR8dHKbQnQK4W.png', 'name': 'Film4 Productions', 'origin_country': 'GB'}, {'id': 500, 'logo_path': None, 'name': 'Goldcrest', 'origin_country': 'GB'}, {'id': 2690, 'logo_path': '/9XXpd39mDfkWmcNB6R0tpvzo781.png', 'name': 'Screen Yorkshire', 'origin_country': 'GB'}, {'id': 2395, 'logo_path': '/pZz4qs03FtP6UGtZ3hjQ6qimcwi.png', 'name': 'HanWay Films', 'origin_country': 'GB'}]
# [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI1uteEwHet.png', 'name': 'DreamWorks Animation', 'origin_country': 'US'}]
# [{'id': 17090, 'logo_path': '/fmCUAzog8B4VVeIAxrmAGMeAmqw.png', 'name': 'FJ Productions', 'origin_country': 'US'}, {'id': 41602, 'logo_path': None, 'name': 'BB Film Productions', 'origin_country': 'US'}]
# [{'id': 6896, 'logo_path': '/2Q89KvzxTKB5BAv9RqFIPI1qb7E.png', 'name': 'EuropaCorp', 'origin_country': 'FR'}, {'id': 2322, 'logo_path': None, 'name': 'The Javelina Film Company', 'origin_country': ''}]
# [{'id': 77552, 'logo_path': None, 'name': 'Curiosa Films', 'origin_country': ''}, {'id': 78936, 'logo_path': '/24F1OFSmF2qAoTLebUrw3soy3g1.png', 'name': 'Cinémage 10', 'origin_country': 'FR'}]
# [{'id': 805, 'logo_path': None, 'name': 'Serendipity Point Films', 'origin_country': 'CA'}]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
to_drop=companies_df[companies_df.production_companies==" "].index
companies_df.drop(to_drop,inplace=True)
to_drop=df[df.imdb_id==''].index
df.drop(to_drop,inplace=True)

# %%
companies_df.production_companies[3331]
# Out:
# "[{'id': 26468, 'logo_path': None, 'name': 'IFC Productions', 'origin_country': ''}, {'id': 728, 'logo_path': None, 'name': 'Kalkaska Productions', 'origin_country': ''}]"

# %%
company_dictionary=list_to_dic('production_companies',companies_df)

# %%
company_dictionary
# Out:
# {'Prime Focus World': 1,
#  'David Ladd Films': 2,
#  'Blue Gardenia Productions': 1,
#  'KC Medien': 3,
#  'Route One Entertainment': 5,
#  'Mofac': 1,
#  'October Films': 1,
#  'Isle of Man Film': 21,
#  'Silvertongue Films': 2,
#  'Common Enemy': 1,
#  'Sigma Films Ltd.': 2,
#  'Scamp Film and Theatre Ltd.': 1,
#  'Trio Pictures': 1,
#  'Vesuvius Productions': 1,
#  'Maeday Productions': 1,
#  'Rat Entertainment': 8,
#  'Amka Films': 1,
#  'Original Force Animation': 1,
#  'CinePostproduction': 1,
#  'Wingman Productions': 3,
#  'What Else? B.V': 1,
#  'Jumping Jack Films': 1,
#  'Someci': 1,
#  'Les productions Chaocorp': 1,
#  '3Pas Studios': 1,
#  'North by Northwest Entertainment': 7,
#  'Uncharted': 1,
#  'Ronalds Brothers Films': 1,
#  'IMG Films': 2,
#  'Goldmann Pictures': 3,
#  'Roth Films': 11,
#  'Prufrock Pictures': 1,
#  'Screen Flanders': 1,
#  'Dice Film': 2,
#  'Big Farm': 1,
#  'Synthetic Filmwerx': 2,
#  'Wild Bunch Germany': 2,
#  'Primo Filmes': 1,
#  'TF1 Studio': 2,
#  'Lighthouse Pictures': 5,
#  'Faliro House Productions': 10,
#  'Cecchi Gori Group Tiger Cinematografica': 2,
#  'Horseshoe Films': 1,
#  'Filmstandort Austria (FISA)': 1,
#  'Misher Films': 10,
#  'Bad Idea': 1,
#  'Finding Forrester Productions': 1,
#  'Union Editorial': 1,
#  'Filmwave Pictures': 1,
#  'MDBF Zweite Filmgesellschaft': 1,
#  'Sparkhouse Media': 1,
#  'Digic Pictures': 1,
#  'Black Fawn Films': 1,
#  'Slovenian Film Fund': 1,
#  'Price Productions': 1,
#  'AEON ENTERTAINMENT CO.LTD': 1,
#  'TSBD Productions': 1,
#  'Mischief Maker Studios': 1,
#  'Content Media Corporation': 1,
#  'Saint Sébastien Froissart': 1,
#  "Dreamin' Dolphin Film": 1,
#  'LINK Entertainment': 4,
#  'Fargo Films': 2,
#  'Josy Films': 2,
#  'Dispictures': 1,
#  'Abandon Entertainment': 1,
#  'WT Canada Productions': 1,
#  'Lumanity Productions': 1,
#  'A Hot Dog': 1,
#  'RKB Mainichi Broadcasting Corporation': 1,
#  'Hunters Prayer Production Spain': 1,
#  'Adventure Pictures': 2,
#  'Code Red': 3,
#  'Redwood Palms Pictures': 2,
#  'Malao Film': 1,
#  'RatPac Documentary Films': 2,
#  'Sony Music Entertainment (JP)': 2,
#  'Double Hope Films': 1,
#  'Columbia Pictures': 243,
#  'Vilaverdén Film': 1,
#  'Screen Tasmania': 4,
#  'Tugawood Pictures': 1,
#  'Divine Light Pictures': 1,
#  'Points West Pictures': 1,
#  'Fusion Films': 1,
#  'Vincent Gallo Films': 1,
#  'Eden Productions': 1,
#  'Lime Orchard Productions': 1,
#  'Birchwood Pictures': 2,
#  'Funny Balloons': 1,
#  'Nulook Production': 1,
#  'Soficinéma 5': 1,
#  'Ten Deeds': 1,
#  'Glasgow Film Office': 1,
#  'Easy Open Productions': 1,
#  'SB Projects': 1,
#  'Postal Code Films': 1,
#  'GA2 Productions': 1,
#  'Sleepwalkers Anonymous': 1,
#  'Action 5': 1,
#  'Cranked Up Films': 1,
#  'Boss Media': 3,
#  'Maple Shade Films': 1,
#  'Martini Films': 4,
#  'Office Augusta Co. Ltd.': 1,
#  'Apple Lane Productions': 1,
#  'Landafar': 1,
#  'Roy Andersson Filmproduktion AB': 1,
#  'Globus-film': 2,
#  'Worldwide Media Group': 1,
#  'Boo Productions': 1,
#  'Institution, The': 2,
#  'Institut Valencià de Cinematografia (IVAC)': 1,
#  'Epidemic Pictures': 1,
#  'Everyman Pictures': 6,
#  'Mare Nostrum Productions': 1,
#  'Patricia Clifford Productions': 1,
#  'Black Entertainment Television (BET)': 1,
#  'Seaside Entertainment': 1,
#  'Furnace': 1,
#  'Camelot Pictures': 5,
#  'Lemming Film': 1,
#  'Stan Lathan TV': 1,
#  'Chockstone Pictures': 5,
#  'Sepia Films': 3,
#  'Digi Art': 2,
#  'erbp': 1,
#  'Green Diamond Entertainment': 1,
#  'CGV Arthouse': 2,
#  'On The Corner Films': 4,
#  'Prophet Screen Partners': 1,
#  'Phoenix Wiley': 1,
#  'Auburn Entertainment': 1,
#  'Native Pictures Productions': 1,
#  'Telecine Productions': 1,
#  'FilmEngine': 9,
#  'Tenth Planet Productions': 3,
#  'Come What May Productions': 1,
#  'Norris Moving Pictures': 1,
#  'One Eye Production': 1,
#  'Bad Biology': 1,
#  'Love Guru Productions': 1,
#  'Exhibit A Pictures': 4,
#  'Wishing Well Pictures': 1,
#  'Top Shelf Productions': 1,
#  'Access Pictures': 1,
#  "Société des Producteurs de L'Angoa": 1,
#  'First Spark Media': 1,
#  'PBS Frontline': 1,
#  'Mayhem Pictures': 5,
#  'The Film Works': 1,
#  'Hidden Empire Film Group': 3,
#  'Sweepstake Productions': 1,
#  'Martinelli Films': 1,
#  'PaperChase Films': 1,
#  'Warner Home Video': 1,
#  'Hallmark Hall of Fame Productions': 5,
#  'Catapult Entertainment Group': 1,
#  'MM Productions': 1,
#  'MRB Productions': 2,
#  'Clockwork Pictures': 1,
#  'Amen Ra Films': 4,
#  'Petrobrás': 1,
#  'Pour Toi Public Productions': 1,
#  'Simon Fields Productions': 1,
#  'DS Films Entertainment': 1,
#  'Sandfairy': 1,
#  'Toscana Promozione': 1,
#  'Danjaq': 5,
#  'Jerkschool Productions': 3,
#  'The Virginia Company LLC': 1,
#  'Opus Film': 5,
#  'Cold Fusion Media Group': 1,
#  'Densetsu': 1,
#  'Noah Media Group': 1,
#  'Gemini Films': 1,
#  'March On Productions': 2,
#  'Creamovies': 1,
#  'Emmett/Furla Films': 28,
#  'Monofonus Press': 1,
#  'Apple': 3,
#  'CD Films': 1,
#  'Compass Entertainment': 1,
#  'Dog Lamp Films': 1,
#  'Troma Entertainment': 3,
#  'Palatine Étoile 11': 2,
#  'The Greenlight Fund': 1,
#  'Fox Searchlight Pictures': 86,
#  'Neue Schönhauser Filmproduktion': 1,
#  'Opix Films': 1,
#  'Akson Studio': 2,
#  'Pelican Productions LLC': 1,
#  'Gather Films': 1,
#  'Nvizible': 1,
#  'Neon': 22,
#  'Iris Films': 1,
#  'Miromar Entertainment': 1,
#  'Unity Productions': 1,
#  'Best Man Filmproduktions': 1,
#  'Touchstone Television': 3,
#  'DCS': 1,
#  'Chugoku Broadcasting (RCC)': 2,
#  'Peninsula Films': 7,
#  'Brooklyn Underground Films': 1,
#  'Vistaar Religare Film Fund': 1,
#  'CJ ENM': 1,
#  'Avex Inc.': 1,
#  'Cine de Garage': 1,
#  'MarVista Entertainment': 11,
#  'Blue Flower Productions': 1,
#  'StoryArk Media': 1,
#  'Laurinfilm': 2,
#  'HR': 1,
#  'Broken Lizard Industries': 5,
#  'WYSJ Media': 3,
#  'Le Pacte': 21,
#  'Kanbar Entertainment': 1,
#  'Sidetrack Films': 1,
#  'Dead Rising Productions': 1,
#  'Bacon & Eggs': 1,
#  'NeeNee Productions': 1,
#  'RKO Pictures LLC': 5,
#  'Midwestern Films': 1,
#  'Doc Society': 1,
#  'Intellectual Properties Worldwide': 3,
#  'Populist Pictures': 1,
#  'Imaj Sound Post Production': 1,
#  'Den Vestdanske Filmpulje': 2,
#  'Grey Water Park Productions': 2,
#  'Feature Film Project': 1,
#  'SModcast Pictures': 3,
#  'Cinémage 5': 1,
#  'British Film Company': 7,
#  'Hackybox Pictures': 1,
#  'Serious Productions': 1,
#  'BB Film Productions': 3,
#  'Canal+': 240,
#  'The Film House': 1,
#  'Generation Blue Films': 2,
#  'Significant Productions': 3,
#  'National Picture Show': 1,
#  'Cinedigm Entertainment': 1,
#  'Willow Films': 1,
#  'Chimichanga Productions': 1,
#  'Warner Bros. France': 1,
#  'Lanistar Media': 1,
#  'ApolloProMovie & Co. 3. Filmproduktion': 1,
#  'Medyapim': 1,
#  'Fear of God Films': 2,
#  'Outpost Studios': 2,
#  'Bunk 11 Pictures': 1,
#  'TDJ Enterprises': 1,
#  '51 Minds Entertainment': 1,
#  'Peace Arch Entertainment Group': 4,
#  'Rhulen Entertainment': 1,
#  'Brick Dust Productions LLC': 1,
#  'Carr-Santelli': 1,
#  'Kinology': 4,
#  'Insurgent Docs': 3,
#  'ITB Productions': 1,
#  'EMJAG Productions': 5,
#  'Film Keyz Production': 1,
#  'Harbor Light Entertainment': 1,
#  'TakaraTomy': 2,
#  'Dutch Filmworks': 1,
#  'Lybian Palette': 1,
#  'Line Research': 1,
#  'Shortcake Productions': 1,
#  'LTB Films Limited': 1,
#  'Estudios Picasso': 3,
#  'Edko Management and Consulting': 1,
#  'Indieproduction': 1,
#  'Battle Mountain Films': 2,
#  'tony montana films': 1,
#  'FilmFondet Fuzz': 2,
#  'Axel Films': 4,
#  'France 3': 3,
#  'OC Film': 1,
#  'Raw Film Productions': 1,
#  'Katalyst Films': 4,
#  'Tremolo Productions': 6,
#  'Audley Films LLP': 1,
#  'Veteran Pictures': 1,
#  'TWC Asian Film Fund': 1,
#  'Media Development Authority (MDA)': 1,
#  'iDeal Partners Film Fund': 5,
#  'SNL Studios': 1,
#  'CTV International': 1,
#  'Julius R. Nasso Productions': 1,
#  'Eight 35': 1,
#  'Cofimage 12': 1,
#  'Maandi Films': 1,
#  'VIP Media': 1,
#  'Aconit Pictures': 1,
#  'Freeform': 1,
#  'Tunnel Post': 3,
#  'Cofinova 5': 2,
#  'Freerunning': 1,
#  'American Cinema International': 1,
#  'Omega Micott Inc.': 1,
#  'Zodiac Features': 1,
#  'Ex3 Productions': 1,
#  'Fuji Television Network': 12,
#  'TNT Premier Studios': 1,
#  'Cinephil': 1,
#  'Conduit': 1,
#  'Filmboard Berlin-Brandenburg (FBB)': 3,
#  'Abe Shuji': 1,
#  'Marquis Productions': 2,
#  'Anvil Films': 3,
#  'Blade Runner Partnership': 1,
#  'Park Pictures Features': 7,
#  'Chinavision Media Group': 1,
#  'Team G': 1,
#  'Film Invaders': 1,
#  'Sidus': 3,
#  'Makeshift Pictures': 1,
#  'LG': 1,
#  'Sofica Soficinéma 4': 2,
#  'Belladonna Productions': 7,
#  'Legacy Pictures': 2,
#  'Cinema Seven Productions': 1,
#  'Claussen+Putz Filmproduktion': 1,
#  'Central Partnership': 3,
#  'Palatine Étoile 10': 2,
#  'Capstone Pictures': 1,
#  'Film United': 1,
#  'Jan Chapman Pictures': 1,
#  'Rothkirch Cartoon Film': 1,
#  'O2 Filmes': 5,
#  'Rohit Shetty Productions': 1,
#  'Alton Road Productions': 1,
#  'What Just Happened Productions': 1,
#  'Kanzeon': 1,
#  'Spartiate Films': 1,
#  'Red Chillies Entertainment': 10,
#  'Vision View Entertainment': 2,
#  'Tube Entertainment': 1,
#  'The Wanting Film': 1,
#  'Lightning Entertainment': 5,
#  'Carcass Studios': 1,
#  'The Orchard': 3,
#  'STANDOFF Pictures': 1,
#  'Ciné B': 1,
#  'Momentum': 1,
#  'Kvinde Films': 1,
#  'The Kraken Films': 2,
#  'East of Harlem (UK) Ltd': 1,
#  'Rakontur': 1,
#  'Derrick Comedy Productions': 1,
#  'Baked Studios': 1,
#  'Fairview Entertainment': 5,
#  'Dragonfly Entertainment': 3,
#  'Wild Side Films': 1,
#  'Frakas Productions': 6,
#  'Elevated Films': 4,
#  'Northern Lights Films': 5,
#  'PraxiScope Productions': 1,
#  'Canonigo Films': 2,
#  'Beta Cinema': 3,
#  'Rat Pack Filmproduktion': 7,
#  'Last Pictures': 1,
#  'Vaudeville Productions': 1,
#  'Production Champion': 1,
#  'Berlanti Productions': 1,
#  'Film Media': 1,
#  'Full Clip Productions': 2,
#  'MAPPA': 1,
#  'Woodhaven Production Company': 1,
#  'Salem Street Entertainment': 4,
#  'Memento Films Distribution': 1,
#  'Cool Beans': 1,
#  'A24': 13,
#  'Anagram Pictures': 2,
#  'Unigram': 1,
#  'Samera Entertainment': 1,
#  'Pandemonium': 3,
#  'Studio Babelsberg StudioBabelsberg Motion Pictures': 1,
#  'Compulsion Inc.': 1,
#  'Huntington Prep': 1,
#  'Unisol 3 Distribution': 1,
#  'Big Cat Productions': 1,
#  'Lanube Películas': 1,
#  'Pirol Stiftung': 1,
#  'King Record Co.': 2,
#  'Metropolitan Films': 2,
#  'Sonia Films': 1,
#  'Film Commission Torino Piemonte': 6,
#  'Bedford Falls Productions': 8,
#  'Hugar Prod': 1,
#  'SF Norge': 2,
#  'Producciones Anhelo': 2,
#  'From Out of Nowhere Productions': 1,
#  'Madam Films': 1,
#  'Eclipse Catering': 3,
#  'Odeon Films': 1,
#  'Pendle Mountain Productions': 1,
#  'Wildling Pictures': 1,
#  'HFD Productions': 1,
#  'Leomax Entertainment': 1,
#  'Choke Film': 1,
#  'H2O Motion Pictures': 2,
#  'Alabama Moon Entertainment': 1,
#  'Senator Entertainment Co': 3,
#  'Prime Entertainment': 1,
#  'Element Pictures': 11,
#  'CN6 Productions': 2,
#  'Capitan Arana': 1,
#  'Halcyon Films': 1,
#  'Arcadia Motion Pictures': 7,
#  'Shangri-La Entertainment': 11,
#  'Meridian Entertainment': 1,
#  'Busca Vida Filmes': 1,
#  'Armada Films': 2,
#  'Omeira Studio Partners': 1,
#  'High Line Productions': 1,
#  'Crown Productions': 1,
#  'Ingenious Senior Film Fund': 1,
#  'Plateau A': 1,
#  'Latitude Films': 1,
#  'John Barry Group': 1,
#  'Artcam y Fonds Sud Cinéma': 1,
#  'Cargo Entertainment': 4,
#  'Cave Pictures': 1,
#  'Winterdance Productions Ltd.': 1,
#  '34th Street Films': 1,
#  'Bedford Falls Company, The': 1,
#  'Synchronicity Films': 2,
#  'Epsilon Motion Pictures': 47,
#  'Wigwam Films': 3,
#  'Netter Productions': 5,
#  'Blackmagic Design Films': 1,
#  'BoulderLight Pictures': 4,
#  'Sladek Taaffe Productions': 1,
#  'Post No Bills Films': 1,
#  'Windy Hill Pictures': 2,
#  'Newgrange Pictures': 2,
#  'Tango Films': 1,
#  'Center for Investigative Reporting': 1,
#  'Tito Clint Movies': 1,
#  'Omega Entertainment': 1,
#  'Corniche Pictures': 1,
#  'Elliptical Wing': 1,
#  'Ascent Film': 2,
#  'Lama Productions': 1,
#  'Sean Bailey Productions': 1,
#  'Barefoot Films': 5,
#  'Kamel Films': 1,
#  'American Entertainment Partners L.P.': 1,
#  'Devilworks': 1,
#  'Very Special Projects': 2,
#  'Madame Films': 2,
#  'Bulbul Films': 1,
#  'Agent Two': 1,
#  'Film Art Media': 1,
#  'Beijing Poly-bona Film Publishing Company': 2,
#  'The Hallmark Channel': 3,
#  'Tempus': 1,
#  'Marubeni': 2,
#  'Universal Cartoon Studios': 6,
#  'Stone River Productions': 1,
#  'Kontsept Film Company': 5,
#  'Generalitat de Catalunya - Departament de Cultura': 2,
#  'Fortis Film Fund': 1,
#  'Heavy Duty Entertainment': 2,
#  'QI Quality International GmbH Co. KG': 2,
#  'Alphaville Productions': 1,
#  'Georgian-Film': 1,
#  'Zadan / Meron Productions': 3,
#  'Wicked of Oz Studios': 1,
#  'Consellería de Cultura e Turismo': 1,
#  "JP's Peace, Love & Happiness Foundation": 1,
#  'Shade Pictures': 1,
#  'The Bureau': 7,
#  'Patalex III Productions Limited': 1,
#  'Central Newsreel and Documentary Film Studio': 1,
#  'Tightrope Pictures': 1,
#  'Ciclic - Région Centre': 1,
#  'Santa Frost Productions': 1,
#  'Rebel Entertainment': 2,
#  'Mountaintop Productions': 2,
#  'Black Label Media': 10,
#  'Lodger Films': 1,
#  'Rakija Films': 1,
#  'Talent International Film Cultural Company': 1,
#  'Thunder Smoke Media': 2,
#  'Ruby Films': 11,
#  'Blue Seraph Productions': 1,
#  'Miso Film': 2,
#  'Graveyard Filmworks': 1,
#  'Contradiction Films': 2,
#  'La Trini': 2,
#  'Contagious Entertainment': 1,
#  'Beluga Tree': 1,
#  'Sor Productions': 1,
#  'Splendid Pictures': 4,
#  'CalMaple Films': 1,
#  'MOOVIE GmbH': 1,
#  'Ego Film Arts': 2,
#  'Goethe Filmproduktion': 1,
#  'BBC Wales': 8,
#  '2 Entertain': 2,
#  'FLX': 1,
#  'Hollywoodmade': 1,
#  'Silver Screen': 1,
#  'Empreinte Cinéma': 1,
#  'Rebel Films': 1,
#  'HBO': 9,
#  'Walking West Entertainment': 1,
#  'Minnow Films': 1,
#  'Mediana Productions Filmgesellschaft': 1,
#  'TV5 Monde': 1,
#  'Carmel Entertainment': 3,
#  'Entity3 Productions': 1,
#  'Joe Murray Productions Inc.': 1,
#  'Failure to Launch Productions': 1,
#  'Montford / Murphy Productions': 1,
#  'Avi Arad Productions': 2,
#  'Mr. Mudd Production': 10,
#  'Yasahi-Mation Productions': 2,
#  'Tabbak': 2,
#  'M6 Studio': 3,
#  'Capacity Pictures': 3,
#  'The Space Program': 1,
#  'Dead Fish Films': 1,
#  'ITV Studios': 1,
#  'BNP Paribas': 2,
#  'Rainforest Productions': 2,
#  'Versus Entertainment': 1,
#  'International Pictures Two': 1,
#  'MoliFilms Entertainment': 1,
#  'JK Film': 1,
#  'Amazing Incorporated': 1,
#  'Tandem Pictures': 1,
#  'WeWork Studios': 1,
#  'Collective, The': 1,
#  'Krabat Filmproduktion': 1,
#  'Haishang Films': 2,
#  'Gran Via': 2,
#  'Rational Packaging Company': 1,
#  'Wider Film Projects': 1,
#  'Adonis Production': 1,
#  'Ex Machina Film Partners': 1,
#  'Alazraki Films': 1,
#  'Sextant Entertainment Group': 1,
#  'Blue Relief Productions': 1,
#  'Mike and Marty Productions': 1,
#  'Love Punch': 1,
#  'Media Design Imaging': 1,
#  'Sentient Entertainment': 1,
#  'Radical Studios': 2,
#  'KDDI Corporation': 5,
#  'ARM Entertainment': 1,
#  'Paquin Entertainment Group': 2,
#  '13 Ghosts Productions Canada Inc.': 1,
#  'Podium Pictures': 1,
#  'Baker Street': 4,
#  'Electronic Arts': 2,
#  'Film Momentum': 1,
#  'Bophana Production': 1,
#  'Appleseed Film Partners': 1,
#  'Marc Graue Recording Studios': 1,
#  'Eon Productions': 6,
#  'R.P. Productions': 6,
#  'Sun Entertainment Culture': 2,
#  'Mark Canton Productions': 3,
#  'Philipp Filmproduction': 1,
#  'Haut et Court Distribution': 1,
#  'Rockinghorse Films': 1,
#  'Lion Share Productions': 2,
#  'New Films International': 1,
#  'NGN Productions': 5,
#  'Atmosphere Entertainment MM': 8,
#  'Rock Island Films': 1,
#  'NALA Films': 7,
#  'Fox Filmes do Brasil': 2,
#  'Storyteller Pictures': 1,
#  'Sortie 22': 1,
#  'Retro-juice Productions': 1,
#  'Side Street Post': 2,
#  'Leverage Entertainment': 1,
#  'Unthank Films': 1,
#  'Langley Productions': 1,
#  'Tucker Tooley Entertainment': 5,
#  'The Ultimate Gift LLC': 1,
#  '33andOut Productions': 1,
#  'Italian International Film': 9,
#  'Red Hour Films': 1,
#  'Tanlay': 1,
#  'Ixtlan': 1,
#  'Post Factory NY': 1,
#  'Nu Image Bulgaria': 2,
#  'Jaguar Films': 1,
#  'IDT Entertainment': 2,
#  'Jeff Brothers Productions': 1,
#  'Warner Music Entertainment': 1,
#  'Lolafilms': 3,
#  'Cinelou Films': 6,
#  'TYO Productions': 2,
#  'Fireflight': 1,
#  'LightWorkers Media': 2,
#  'Colossal Entertainment': 1,
#  'Keel Films': 1,
#  'Zeta Cinema': 2,
#  'LJ Film': 2,
#  'Internationale Filmproduktion Poseidon': 1,
#  "Conseil Régional de Provence-Alpes Côte d'Azur": 1,
#  'Hasbro Studios': 8,
#  'Stardust Pictures': 1,
#  'Ed Friendly Productions': 1,
#  'double A Films': 1,
#  'WeatherVarie Productions': 1,
#  'Televiziunea Română': 1,
#  'Twin Co. Ltd.': 1,
#  'Matinee Pictures': 1,
#  'TAT Productions': 1,
#  'Inwood Road Films': 1,
#  'Prometheus Entertainment': 1,
#  'Bruin Grip Services': 2,
#  'Sunrise Pictures': 3,
#  'Klasky-Csupo': 2,
#  'Gilbert Films': 7,
#  'DMC Film': 1,
#  'Y Productions': 1,
#  'Modernciné': 4,
#  'MMC Joule Films': 1,
#  'Zoic Studios': 1,
#  'Universal Pictures Germany GmbH': 1,
#  'Maven Pictures': 12,
#  'April Productions': 1,
#  'Greenroom Entertainment': 1,
#  'Keystone Family Pictures': 1,
#  'Les films du 10': 1,
#  'IndieVest Pictures': 1,
#  'Lightstream Pictures': 2,
#  'Irwin Entertainment': 4,
#  'Nervous Tick': 2,
#  'Whenua Films': 2,
#  'Knowledge & Creation Ventures': 1,
#  '120 Films': 7,
#  'Reverence Gospel Media': 1,
#  'Smoking Gun Productions': 1,
#  'Johnson & Johnson Spotlight Presentations': 1,
#  'Visual Arts Entertainment': 2,
#  'Taken 2': 1,
#  'Monarch Pictures': 2,
#  'Codex Pictures': 1,
#  'Hat and Coat Productions': 1,
#  'Junction Entertainment': 3,
#  'Captivate Entertainment': 2,
#  'Optix Digital Pictures': 1,
#  'LBI Productions': 2,
#  'KNR Productions': 1,
#  'Ici & Là Productions': 1,
#  'Kismet Entertainment Group': 3,
#  'Arbaaz Khan Productions': 1,
#  'Kansha Films': 1,
#  'Von Zerneck Sertner Films': 4,
#  'GFT Entertainment': 4,
#  'Tabo Tabo Films': 1,
#  'Van Hoy/Knudsen Productions': 1,
#  'North Box Productions': 1,
#  'Cofimage 23': 1,
#  'Rocklin / Faust': 1,
#  'Okeanos Foundation for the Sea': 1,
#  'Cinephile': 1,
#  'Creative Projects Group': 1,
#  'Prospect Park': 3,
#  'Récifilms': 3,
#  'Scared Sheetless': 1,
#  'STX Films': 1,
#  'Double Dare You Productions': 5,
#  'Yle': 8,
#  'Moetion Films': 1,
#  'Studio Chizu': 3,
#  'Picture Rock Entertainment': 1,
#  'Headmon Entertainment & Productions': 1,
#  'Arramis Films': 2,
#  'FilmFernsehFonds Bayern': 2,
#  'Taewon Entertainment': 1,
#  'Mind the GAP Productions': 1,
#  'Snow Globe Productions': 1,
#  'Protagonist Pictures': 12,
#  'Avalanche Films': 1,
#  'FFA': 12,
#  'Foqus Arte Digital': 1,
#  'Cloud Ten Pictures': 2,
#  'Hamilton Films': 1,
#  'Digiart Productions': 2,
#  'Chic Films': 4,
#  'Oriol Colomar': 1,
#  'Other Angle Pictures': 1,
#  'Bungalow Media + Entertainment': 1,
#  'City on a Hill Productions': 2,
#  'Dark Horse Entertainment': 9,
#  'MGM Television': 2,
#  'Rai Cinema': 62,
#  "Fonds Eurimages du Conseil de l'Europe": 9,
#  "The Donners' Company": 12,
#  'Isabella Films BV': 1,
#  'Baltimore Pictures': 1,
#  'Institut Català de les Indústries Culturals': 1,
#  'Treehead Films': 1,
#  'StudioCanal Image': 1,
#  'Bagman (2009)': 1,
#  'Silver Nitrate': 7,
#  'Autopilot Entertainment': 1,
#  'In Association with Productions': 1,
#  'The Jacobson Company': 4,
#  'StoryBoard Media': 1,
#  '14ème Art Production': 1,
#  'Rooks Nest Entertainment': 6,
#  'Realmbuilders Productions': 1,
#  'Neue Road Movies': 3,
#  'Southpaw Entertainment': 4,
#  'ApolloProScreen Filmproduktion': 2,
#  'PubRes': 1,
#  'React To Film': 1,
#  'Sara Fost Pictures': 1,
#  'Pulse Films': 3,
#  'Supercollider Productions': 1,
#  'Sony Pictures Productions': 1,
#  'Granada Television': 2,
#  'HorsePower Entertainment': 2,
#  'Versus Pictures': 1,
#  'BMG': 1,
#  'Helix Media Group': 1,
#  'StudioCanal': 151,
#  '40 Acres & A Mule Filmworks': 12,
#  'Guy Walks into a Bar Productions': 2,
#  'Mighty Engine': 2,
#  'Screen Division': 2,
#  'Cineritmo': 1,
#  'Paco Cinematografica': 2,
#  'Younger Than You': 2,
#  'Mirabelle Pictures Productions': 1,
#  'Echolands Creative Group': 1,
#  'Gummshoe Productions': 1,
#  'Hartswood Films': 1,
#  '24P Media Group': 1,
#  'Lavender Pictures': 1,
#  'Capital Markets Film Finance': 1,
#  'Slater Hall Productions': 1,
#  'Caliber Media Company': 7,
#  'Land Films Inc.': 2,
#  'Animation DO': 3,
#  'Radical Pictures': 1,
#  'Else Films': 1,
#  'Zucker Productions': 1,
#  'Apart Films': 1,
#  'ROBOT': 3,
#  'Modern Man Films': 1,
#  'Darwin Collective, The': 1,
#  'Fangoria Films': 2,
#  'Hanover Films': 2,
#  'Sofica Manon 3': 1,
#  'Beijing Weiyingshidai Culture & Media': 1,
#  'The Secret Garden': 1,
#  'Rose Pictures': 1,
#  'Warner Bros. Japan': 3,
#  'Sunflower Productions': 1,
#  'Pathé Renn Productions': 11,
#  'Angry Monkey Entertainment': 1,
#  'Raven Banner Entertainment': 1,
#  'Belfius': 1,
#  'Milkyway Image Company': 5,
#  'The Halcyon Company': 1,
#  'Cinéventure Développement 3': 1,
#  'AOI Promotion': 1,
#  'Pop Films': 3,
#  'Between The Eyes': 2,
#  'Windowseat Films': 1,
#  'Hualien Media International': 1,
#  'DirecTV': 2,
#  'NBC Universal Global Networks': 1,
#  'Newmarket Films': 1,
#  'Chydzik Media Group': 1,
#  'MVK': 1,
#  "Traveler's Rest Films": 1,
#  'Sigma Film Productions': 1,
#  'We Came, We Saw, We Conquered Studios': 1,
#  'Mob Scene Creative Productions': 1,
#  'Clipsal Films': 1,
#  'Tripod Entertainment': 1,
#  'Ehud Releasing': 1,
#  'Braveart Films': 1,
#  'Another Park Film': 1,
#  'Global Emerging Markets (GEM)': 1,
#  'Terra Mater Factual Studios': 1,
#  'Atmospheric Pictures': 1,
#  'ABC Signature': 1,
#  'Runteam III Ltd.': 1,
#  'Infogrames Entertainment': 1,
#  'Lunch Box Entertainment': 1,
#  'Braven Films': 2,
#  'Farrell Paura Productions': 1,
#  'Untitled Entertainment': 3,
#  'Studio Image Soficas': 1,
#  'International Keystone Entertainment': 1,
#  'Senator Global Productions': 1,
#  '3Foot7': 1,
#  'Mythmaker Productions': 2,
#  'Shoreline Entertainment': 2,
#  'Ninja Production Services': 1,
#  'In The Groove': 1,
#  'Miramax': 88,
#  'Access Industries': 1,
#  'IDL Films': 1,
#  'Busted Shark Productions': 3,
#  'Matchbox Pictures': 2,
#  'Hemisphere Motion Picture Partners': 1,
#  'Stairway': 1,
#  '777 Films Corporation': 3,
#  'Unipol': 1,
#  'Monumental Pictures': 1,
#  'Magnolia Pictures': 14,
#  'Pigeon Creek Films': 1,
#  'Redwave Films': 2,
#  'Bottom Line Entertainment': 2,
#  'Prairie Home Productions': 1,
#  'Desertlands Entertainment': 1,
#  'Duran': 1,
#  'Oscar Kramer S.A.': 1,
#  'Pig Newton': 3,
#  'Blacklist Digital': 1,
#  'Apple Corps': 1,
#  'RSVP Entertainment': 1,
#  'Berserker Entertainment': 1,
#  'Walking Out': 1,
#  'Nickelodeon Movies': 28,
#  'Higher Ground Productions': 1,
#  'The Königsberg Company': 1,
#  'Marzipan Productions': 1,
#  'Wintergreen Productions': 7,
#  'Furia de Titanes II, A.I.E.': 1,
#  'Pisces Rising Productions': 1,
#  'Tape Productions Inc.': 1,
#  'Phanta Basta!': 1,
#  'Dog Eat Dog Films': 4,
#  'DC Entertainment': 80,
#  'Jason Aron Media': 1,
#  'Gunny Entertainment': 1,
#  'More Films': 1,
#  'Cube Vision': 8,
#  'VIP 3 Medienfonds': 5,
#  'Dog Run Pictures': 1,
#  'Pandora Pictures': 2,
#  'Code 39 Films': 1,
#  'Resonance Film & Video': 1,
#  'Huayi Brothers Media Corporation': 1,
#  'ONO': 2,
#  'SE8 Group': 1,
#  'Barraboy Films': 1,
#  'Sky Movies': 1,
#  'Rice Films': 2,
#  "Needle's Eye Productions": 2,
#  'Explorer Entertainment': 1,
#  'VER': 1,
#  'Caroline Films': 1,
#  'MXN Entertainment': 2,
#  'Phase 4 Films': 2,
#  'Madrose Productions': 1,
#  'CinéGroupe': 1,
#  'Boy Wonder Films': 1,
#  'Artists First': 1,
#  'Caméra One': 3,
#  'Miracle Pictures': 2,
#  'Filmmuse Productions': 1,
#  'Annapurna Pictures': 27,
#  'Geetha Arts': 1,
#  'Oy Bufo Ab': 1,
#  'The Glasgow Film Fund': 2,
#  'Rocklock Films': 1,
#  'Hellinger / Doll Filmproduktion': 2,
#  'Blenkov & Schønnemann ApS': 1,
#  'ACH': 1,
#  'Pontas Film & Literary Agency': 1,
#  'Aries [jp]': 1,
#  'Voodoo Production Services': 3,
#  'Nigel Productions': 1,
#  'Tribeca Productions': 16,
#  'Magic Bear Productions': 1,
#  'Oxymoron Entertainment': 3,
#  'Deep Films': 1,
#  'Sofica Manon 7': 1,
#  'HIPZEE': 1,
#  'Echo Productions': 1,
#  'Huayi Brothers Pictures': 4,
#  'Spectrum Effects': 1,
#  'Salty Film': 1,
#  'IMM Venture Capital': 1,
#  'Estudio Mariscal': 1,
#  'ICI Radio-Canada Télé': 1,
#  'Amblin Entertainment': 34,
#  'Amazon Studios': 23,
#  'Yucaipa Films': 5,
#  'MoviePass Films': 2,
#  'Atomic Entertainment': 1,
#  'Amiguetes Entertainment': 4,
#  'Rainmaker Studios': 8,
#  'TOKYOPOP': 1,
#  'Inevitable Pictures': 1,
#  'Carbunkle Cartoons': 1,
#  'Dragon Blood Holdings': 1,
#  'Splendid Film': 10,
#  'Rainforest Entertainment': 6,
#  'Paradox Produksjon': 5,
#  'Tiger Aspect Productions': 6,
#  'Lord Danger': 1,
#  'Mill Film': 1,
#  'Warner Bros. Korea': 4,
#  'On the Road': 1,
#  'Les Robins des Bois Airlines': 1,
#  'Los Güeros Films': 1,
#  'Cho Man Ro Enterprises': 1,
#  'KirchMedia': 2,
#  'Scout Productions': 2,
#  'The Documentary Group': 1,
#  'Vortex Sutra': 2,
#  'Shanghai PMF Media': 1,
#  'Nouvelles Éditions de Films (NEF)': 3,
#  'Automatik Entertainment': 34,
#  'Natixis Coficiné': 3,
#  'Pan-Européenne': 4,
#  'Nvizage': 1,
#  'Little Punk': 2,
#  'War Dog Productions': 1,
#  'PeaceOut Productions': 2,
#  'Wanko Toys': 1,
#  'Cruzando el desierto A.I.E.': 1,
#  'Movierock': 2,
#  'Presidio': 1,
#  'Reposado Producciones': 1,
#  'Q Television': 1,
#  'Impact Pictures': 9,
#  'Brothers K Productions': 1,
#  'Taiko Studios': 1,
#  '3ality Digital Entertainment': 1,
#  'Fubar Films': 1,
#  'Far Hills Pictures': 1,
#  'Prohibition Pictures': 1,
#  'Tessalit Productions': 3,
#  'Lampray': 1,
#  'ApolloScreen Filmproduktion GmbH & Co. Filmproduktion KG': 2,
#  'Egg Film': 1,
#  'Dragon Studios': 1,
#  'Making Movies': 1,
#  'Taking a Line for a Walk Productions': 1,
#  'Fábrica de Cine': 2,
#  'Lionsgate Television': 1,
#  'Anka Film': 1,
#  'Kallouche Cinéma': 1,
#  'Furious FX': 1,
#  'Access Films': 1,
#  'Kross Pictures': 1,
#  'Michael Grandage Company': 1,
#  'Beijing Bu Yi Le Hu Film Company': 1,
#  'Company Films': 6,
#  'Nikkatsu Pictures': 3,
#  'De Line Pictures': 12,
#  'Rox Productions': 1,
#  'Movie Trailer House': 1,
#  'Hostel LLC': 1,
#  'Union Générale Cinématographique (UGC)': 6,
#  'Maguire Entertainment': 3,
#  'Kasander Film Company': 2,
#  'Cartoon Saloon': 3,
#  'Firm, The': 1,
#  'Woss Group Film Productions': 3,
#  'Double Windsor Films': 1,
#  'Digital Image Associates': 3,
#  'Costa Films': 2,
#  'Our House Films': 1,
#  'Level 10 Films': 1,
#  'Movic': 1,
#  'The Goatsingers': 1,
#  'Tube Pictures': 1,
#  'Blitz Films': 1,
#  'CIPI Cinematografica S.A.': 1,
#  'Maple Road Pictures': 1,
#  'Sound Venture Productions': 1,
#  'Dimension Films': 86,
#  'Walden Media': 32,
#  'Illuminations Films': 1,
#  'Pierpoline Films': 1,
#  'Eastern Sunrise Films': 1,
#  'Particle Fever': 1,
#  'Ouille Productions': 3,
#  'IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG': 6,
#  'Gambit Pictures': 1,
#  'Les Enfants Terribles': 1,
#  'UFA International Film & TV Production GmbH': 1,
#  'Sasquatch Films': 1,
#  "Girls' Club Entertainment": 1,
#  'Vintage Pictures': 2,
#  'Envision Media Arts': 3,
#  'EUE/Screen Gems Studios': 1,
#  'Red Horse Films': 1,
#  'Gaylord Films': 7,
#  'Halt Productions': 1,
#  ...}

# %%
companies_df
# Out:
#           id                       title    imdb_id  \
# 0     475557                       Joker  tt7286456
# 1     299536      Avengers: Infinity War  tt4154756
# 2     271110  Captain America: Civil War  tt3498820
# 3     430155                        Coma  tt6087226
# 4      27205                   Inception  tt1375666
# ...      ...                         ...        ...
# 9975  206324          Bhaag Milkha Bhaag  tt2356180
# 9976  424344      Gaspard at the Wedding  tt5729818
# 9977   25927               Staten Island  tt0976246
# 9978    7973                     Caramel  tt0825236
# 9979  421851  Michael Moore in TrumpLand  tt6163356
#
#                                                  genres  \
# 0     [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 2     [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3     [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# ...                                                 ...
# 9975  [{'id': 36, 'name': 'History'}, {'id': 28, 'na...
# 9976  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 9977  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 9978  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 9979                [{'id': 99, 'name': 'Documentary'}]
#
#                                                overview     budget  \
# 0     During the 1980s, a failed stand-up comedian i...   55000000
# 1     As the Avengers and their allies have continue...  300000000
# 2     Following the events of Age of Ultron, the col...  250000000
# 3     A young and talented architect comes to his se...    4000000
# 4     Cobb, a skilled thief who commits corporate es...  160000000
# ...                                                 ...        ...
# 9975  The true story of the "Flying Sikh" world cham...    4600000
# 9976  After keeping a careful distance for many year...          0
# 9977  Sully (Ethan Hawke) is desperate to give his u...          0
# 9978  In a beauty salon in Beirut the lives of five ...          0
# 9979  Oscar-winner Michael Moore dives right into ho...          0
#
#       release_year  release_month  popularity  vote_count  vote_average  \
# 0             2019             10      80.757       14346           8.2
# 1             2018              4      77.294       19348           8.3
# 2             2016              4      69.266       16650           7.4
# 3             2019             11      59.127         157           6.0
# 4             2010              7      69.553       26852           8.3
# ...            ...            ...         ...         ...           ...
# 9975          2013              7       8.242         147           7.6
# 9976          2017             10       5.052          85           6.2
# 9977          2009              2       6.899          47           6.2
# 9978          2007              7       5.988         138           6.9
# 9979          2016             10       7.978          66           6.2
#
#          revenue runtime                               production_companies  \
# 0     1074251311     122  [{'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp...
# 1     2046239637     149  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 2     1153296293     147  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 3        2363584     111  [{'id': 29924, 'logo_path': None, 'name': 'Fre...
# 4      825532764     148  [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8D...
# ...          ...     ...                                                ...
# 9975    25000000     186  [{'id': 6808, 'logo_path': '/xa1Yz7B5eRC2F9oHA...
# 9976           0     103  [{'id': 11773, 'logo_path': '/8fCjsqh43LbPV6pm...
# 9977           0      96  [{'id': 729, 'logo_path': '/hNxGdbddbsDDnEWJ7R...
# 9978           0      96  [{'id': 208, 'logo_path': '/bxQYlRhQu6nbohBEL0...
# 9979           0      73  [{'id': 76082, 'logo_path': None, 'name': 'IMG...
#
#                                    production_countries  \
# 0     [{'id': 9993, 'logo_path': '/2Tc1P3Ac8M479naPp...
# 1     [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 2     [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 3     [{'id': 29924, 'logo_path': None, 'name': 'Fre...
# 4     [{'id': 923, 'logo_path': '/5UQsZrfbfG2dYJbx8D...
# ...                                                 ...
# 9975  [{'id': 6808, 'logo_path': '/xa1Yz7B5eRC2F9oHA...
# 9976  [{'id': 11773, 'logo_path': '/8fCjsqh43LbPV6pm...
# 9977  [{'id': 729, 'logo_path': '/hNxGdbddbsDDnEWJ7R...
# 9978  [{'id': 208, 'logo_path': '/bxQYlRhQu6nbohBEL0...
# 9979  [{'id': 76082, 'logo_path': None, 'name': 'IMG...
#
#                               production_companies_list
# 0     [DC Entertainment, Warner Bros. Pictures, DC C...
# 1                                      [Marvel Studios]
# 2                                      [Marvel Studios]
# 3     [Fresh Film, Cinema Fund, Mars Media Entertain...
# 4     [Legendary Entertainment, Syncopy, Warner Bros...
# ...                                                 ...
# 9975                        [Viacom 18 Motion Pictures]
# 9976  [Artémis Productions, Agat Films & Cie, Centre...
# 9977  [Why Not Productions, EuropaCorp, Open City Fi...
# 9978  [Bac Films, Les Films des Tournelles, Les Film...
# 9979                     [IMG Films, Dog Eat Dog Films]
#
# [9978 rows x 16 columns]

# %%
companies_df.production_companies_list[0]
# Out:
# ['DC Entertainment',
#  'Warner Bros. Pictures',
#  'DC Comics',
#  'Joint Effort',
#  'Village Roadshow Pictures',
#  'Bron Studios',
#  'Creative Wealth Media Finance',
#  'DC Films',
#  '22 & Indiana Pictures']
