# %% [markdown]
# # Movie Metadata

# %%
#https://www.kaggle.com/rounakbanik/the-movies-dataset/data?select=ratings.csv - Origin of data
#importing necessary libraries
import pandas as pd
import numpy as np

# %%
#loading necessary csv files
movies_md=pd.read_csv('movies_metadata.csv')
ratings=pd.read_csv('ratings.csv')
# Out:
# /Users/carlosruiz/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#dropping uncessesary columns
movies_md.drop(['belongs_to_collection','homepage','original_language','original_title','poster_path','status','tagline','video'],axis=1,inplace=True)

# %%
#removing adult movies
movies_md.drop(list(movies_md.loc[movies_md['adult']=='True'].index),axis=0,inplace=True)
movies_md.drop('adult',axis=1,inplace=True)

# %%
#removing unecessry null values
movies_md.dropna(axis=0,how = 'any', subset= ['production_companies','title'],inplace= True )

# %%
def namefix(values):
    """
    namefind(list)
    
    Namefind takes in a list of dictionaries and returns the name key of said dictionary as an ordered list and appends 
    the list of values to the list provied. 
    
    x=[{'id': 1, 'name': 'Michael'}, {'id': 2, 'name': 'Sam'}, {'id': 3, 'name': 'Fangfang'}]
    namefind(x)
    x=['Michael','Sam','Fangfang']
    
    
    """
    hold=[]
    for a in range(len(values)):
        for i in range(len(values[a])):
            hold.append(values[a][i]['name'])
        values[a]=hold
        hold=[]

# %%
#cleaning columns and assigning values

ids= [int(key) for key in movies_md.id]
#movies_md.id=ids

produ_count= [eval(key) for key in movies_md.production_countries]
#namefind(produ_count)

language=[eval(key) for key in movies_md.spoken_languages]
#namefind(language)

production= [eval(key) for key in movies_md.production_companies]
#namefind(production)

gen = [eval(key) for key in movies_md.genres]
#namefind(gen)

# %%
#assigning new values to respective columns

movies_md.spoken_languages=language

movies_md.production_countries=produ_count

movies_md.genres=gen

movies_md.production_companies=production

# %%
movies_md['id'] = movies_md['id'].astype('int64')

# %%
movies_md.head()
# Out:
#      budget                                             genres     id  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4         0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#      imdb_id                                           overview popularity  \
# 0  tt0114709  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  tt0113497  When siblings Judy and Peter discover an encha...    17.0155
# 2  tt0113228  A family wedding reignites the ancient feud be...    11.7129
# 3  tt0114885  Cheated on, mistreated and stepped on, the wom...    3.85949
# 4  tt0113041  Just when George Banks has recovered from his ...    8.38752
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0

# %%
#reorganizing columns and rows more cohesively
column_titles=['id','title','imdb_id','genres','overview','release_date','runtime','popularity','vote_count','vote_average','budget','revenue','production_companies','production_countries','spoken_languages']
movies_md=movies_md.reindex(columns=column_titles)
movies_md.reset_index(inplace=True)
movies_md.head()
# Out:
#    index     id                        title    imdb_id  \
# 0      0    862                    Toy Story  tt0114709
# 1      1   8844                      Jumanji  tt0113497
# 2      2  15602             Grumpier Old Men  tt0113228
# 3      3  31357            Waiting to Exhale  tt0114885
# 4      4  11862  Father of the Bride Part II  tt0113041
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             overview release_date  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30     81.0
# 1  When siblings Judy and Peter discover an encha...   1995-12-15    104.0
# 2  A family wedding reignites the ancient feud be...   1995-12-22    101.0
# 3  Cheated on, mistreated and stepped on, the wom...   1995-12-22    127.0
# 4  Just when George Banks has recovered from his ...   1995-02-10    106.0
#
#   popularity  vote_count  vote_average    budget      revenue  \
# 0    21.9469      5415.0           7.7  30000000  373554033.0
# 1    17.0155      2413.0           6.9  65000000  262797249.0
# 2    11.7129        92.0           6.5         0          0.0
# 3    3.85949        34.0           6.1  16000000   81452156.0
# 4    8.38752       173.0           5.7         0   76578911.0
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                                     spoken_languages
# 0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           [{'iso_639_1': 'en', 'name': 'English'}]
# 3           [{'iso_639_1': 'en', 'name': 'English'}]
# 4           [{'iso_639_1': 'en', 'name': 'English'}]

# %%
#end

# %%
movies_md.to_csv('movies_md.csv', index=False)

# %%
df1=movies_md[['id','title']]

# %%
df2=ratings[['movieId','rating']]
df2.columns=['id', 'rating']
df2.size
# Out:
# 52048578

# %%
df3=pd.merge(df1,df2, on='id', how='left' )

# %%
ratings.loc[ratings.movieId==862]
# Out:
#           userId  movieId  rating  timestamp
# 184624      1923      862     3.0  858335006
# 200490      2103      862     5.0  946044912
# 524001      5380      862     1.0  878941641
# 610887      6177      862     4.0  859415226
# 643892      6525      862     4.0  857388995
# ...          ...      ...     ...        ...
# 25788364  268336      862     4.0  955427492
# 25798428  268391      862     3.0  856529977
# 25814740  268568      862     2.0  943826734
# 25980015  270422      862     4.0  941664133
# 26001292  270654      862     4.0  976204090
#
# [374 rows x 4 columns]

# %%
ratings2=pd.read_csv('ratings_small.csv')

# %%
ratings2.loc[ratings2.movieId==862]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %%
movies_md['genres'][2]
# Out:
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]

# %%
 
def namefind(name,column):
    """
   namefind(name_to_find, column_name)
    
    Namefind takes a name that you are trying to locate in the column specified dictionary and returns 
    the index of the dataframe that contains said name.
    
    
    namefind('Comedy','genre')
    
    index                                                                   1
    id                                                                   8844
    title                                                             Jumanji
    genres                                    [{'id': 12, 'name': 'Adventure'},
                                                 {'id': 14, 'name': 'Fantasy'},
                                               {'id': 10751, 'name': 'Family'}] 
    """
    loc_list=[]
    for i in range(len(movies_md[column])):
        for d in range(len(movies_md[column][i])):
            if movies_md[column][i][d]['name']==name:
                loc_list.append(i)
    return(movies_md.loc[loc_list])

# %%
pixar=namefind('Pixar Animation Studios','production_companies')

# %%
pixar.groupby('release_date').count()
# Out:
#               index  id  title  imdb_id  genres  overview  runtime  \
# release_date
# 1984-12-17        1   1      1        1       1         1        1
# 1986-08-17        1   1      1        1       1         1        1
# 1987-08-17        1   1      1        1       1         1        1
# 1988-08-01        1   1      1        1       1         1        1
# 1989-01-01        1   1      1        1       1         1        1
# 1995-10-30        1   1      1        1       1         1        1
# 1997-11-24        1   1      1        1       1         1        1
# 1998-11-25        1   1      1        1       1         1        1
# 1999-10-30        1   1      1        1       1         1        1
# 2000-11-01        1   1      1        1       1         1        1
# 2001-11-01        1   1      1        1       1         1        1
# 2002-05-24        1   1      1        1       1         1        1
# 2003-05-30        1   1      1        1       1         1        1
# 2003-11-04        1   1      1        1       1         1        1
# 2004-11-05        1   1      1        1       1         1        1
# 2004-12-31        1   1      1        1       1         1        1
# 2005-06-21        1   1      1        1       1         1        1
# 2006-06-08        1   1      1        1       1         1        1
# 2006-07-27        1   1      1        1       1         1        1
# 2006-12-28        1   1      1        1       1         1        1
# 2007-06-22        1   1      1        1       1         1        1
# 2007-11-06        1   1      1        1       1         1        1
# 2008-06-18        1   1      1        1       1         1        1
# 2008-06-22        1   1      1        1       1         1        1
# 2008-11-17        1   1      1        1       1         1        1
# 2009-05-13        1   1      1        1       1         1        1
# 2009-05-28        1   1      1        1       1         1        1
# 2009-11-09        1   1      1        1       1         1        1
# 2009-11-10        1   1      1        1       1         1        1
# 2010-06-16        1   1      1        1       1         1        1
# 2010-06-17        1   1      1        1       1         1        1
# 2011-01-01        1   1      1        1       1         1        1
# 2011-06-11        1   1      1        1       1         1        1
# 2011-06-16        1   1      1        1       1         1        1
# 2011-08-04        1   1      1        1       1         1        1
# 2011-11-23        1   1      1        1       1         1        1
# 2012-01-01        1   1      1        1       1         1        1
# 2012-06-21        1   1      1        1       1         1        1
# 2012-09-14        1   1      1        1       1         1        1
# 2013-02-12        1   1      1        1       1         1        1
# 2013-06-20        1   1      1        1       1         1        1
# 2013-10-15        1   1      1        1       1         1        1
# 2014-12-02        1   1      1        1       1         1        1
# 2015-06-09        1   1      1        1       1         1        1
# 2015-06-21        1   1      1        1       1         1        1
# 2015-11-03        1   1      1        1       1         1        1
# 2015-11-14        1   1      1        1       1         1        1
# 2015-11-25        1   1      1        1       1         1        1
# 2016-06-16        2   2      2        2       2         2        2
# 2017-06-15        1   1      1        1       1         1        1
# 2017-06-16        1   1      1        1       1         1        1
#
#               popularity  vote_count  vote_average  budget  revenue  \
# release_date
# 1984-12-17             1           1             1       1        1
# 1986-08-17             1           1             1       1        1
# 1987-08-17             1           1             1       1        1
# 1988-08-01             1           1             1       1        1
# 1989-01-01             1           1             1       1        1
# 1995-10-30             1           1             1       1        1
# 1997-11-24             1           1             1       1        1
# 1998-11-25             1           1             1       1        1
# 1999-10-30             1           1             1       1        1
# 2000-11-01             1           1             1       1        1
# 2001-11-01             1           1             1       1        1
# 2002-05-24             1           1             1       1        1
# 2003-05-30             1           1             1       1        1
# 2003-11-04             1           1             1       1        1
# 2004-11-05             1           1             1       1        1
# 2004-12-31             1           1             1       1        1
# 2005-06-21             1           1             1       1        1
# 2006-06-08             1           1             1       1        1
# 2006-07-27             1           1             1       1        1
# 2006-12-28             1           1             1       1        1
# 2007-06-22             1           1             1       1        1
# 2007-11-06             1           1             1       1        1
# 2008-06-18             1           1             1       1        1
# 2008-06-22             1           1             1       1        1
# 2008-11-17             1           1             1       1        1
# 2009-05-13             1           1             1       1        1
# 2009-05-28             1           1             1       1        1
# 2009-11-09             1           1             1       1        1
# 2009-11-10             1           1             1       1        1
# 2010-06-16             1           1             1       1        1
# 2010-06-17             1           1             1       1        1
# 2011-01-01             1           1             1       1        1
# 2011-06-11             1           1             1       1        1
# 2011-06-16             1           1             1       1        1
# 2011-08-04             1           1             1       1        1
# 2011-11-23             1           1             1       1        1
# 2012-01-01             1           1             1       1        1
# 2012-06-21             1           1             1       1        1
# 2012-09-14             1           1             1       1        1
# 2013-02-12             1           1             1       1        1
# 2013-06-20             1           1             1       1        1
# 2013-10-15             1           1             1       1        1
# 2014-12-02             1           1             1       1        1
# 2015-06-09             1           1             1       1        1
# 2015-06-21             1           1             1       1        1
# 2015-11-03             1           1             1       1        1
# 2015-11-14             1           1             1       1        1
# 2015-11-25             1           1             1       1        1
# 2016-06-16             2           2             2       2        2
# 2017-06-15             1           1             1       1        1
# 2017-06-16             1           1             1       1        1
#
#               production_companies  production_countries  spoken_languages
# release_date
# 1984-12-17                       1                     1                 1
# 1986-08-17                       1                     1                 1
# 1987-08-17                       1                     1                 1
# 1988-08-01                       1                     1                 1
# 1989-01-01                       1                     1                 1
# 1995-10-30                       1                     1                 1
# 1997-11-24                       1                     1                 1
# 1998-11-25                       1                     1                 1
# 1999-10-30                       1                     1                 1
# 2000-11-01                       1                     1                 1
# 2001-11-01                       1                     1                 1
# 2002-05-24                       1                     1                 1
# 2003-05-30                       1                     1                 1
# 2003-11-04                       1                     1                 1
# 2004-11-05                       1                     1                 1
# 2004-12-31                       1                     1                 1
# 2005-06-21                       1                     1                 1
# 2006-06-08                       1                     1                 1
# 2006-07-27                       1                     1                 1
# 2006-12-28                       1                     1                 1
# 2007-06-22                       1                     1                 1
# 2007-11-06                       1                     1                 1
# 2008-06-18                       1                     1                 1
# 2008-06-22                       1                     1                 1
# 2008-11-17                       1                     1                 1
# 2009-05-13                       1                     1                 1
# 2009-05-28                       1                     1                 1
# 2009-11-09                       1                     1                 1
# 2009-11-10                       1                     1                 1
# 2010-06-16                       1                     1                 1
# 2010-06-17                       1                     1                 1
# 2011-01-01                       1                     1                 1
# 2011-06-11                       1                     1                 1
# 2011-06-16                       1                     1                 1
# 2011-08-04                       1                     1                 1
# 2011-11-23                       1                     1                 1
# 2012-01-01                       1                     1                 1
# 2012-06-21                       1                     1                 1
# 2012-09-14                       1                     1                 1
# 2013-02-12                       1                     1                 1
# 2013-06-20                       1                     1                 1
# 2013-10-15                       1                     1                 1
# 2014-12-02                       1                     1                 1
# 2015-06-09                       1                     1                 1
# 2015-06-21                       1                     1                 1
# 2015-11-03                       1                     1                 1
# 2015-11-14                       1                     1                 1
# 2015-11-25                       1                     1                 1
# 2016-06-16                       2                     2                 2
# 2017-06-15                       1                     1                 1
# 2017-06-16                       1                     1                 1
