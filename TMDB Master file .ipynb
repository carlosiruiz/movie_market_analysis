# %% [markdown]
# # TMDB Master file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tmdb=pd.read_csv('tmdb_data',  lineterminator='\n')

# %%
tmdb.drop(['Unnamed: 0','genre_ids'], axis= 1,inplace=True)

# %%
tmdb.head()
# Out:
#    popularity  vote_count  video      id  adult original_language  \
# 0      40.636       14611  False  299534  False                en
# 1      36.426       21849  False   19995  False                en
# 2      31.247       14812  False  140607  False                en
# 3      82.930       19327  False  299536  False                en
# 4      30.958       15896  False  135397  False                en
#
#                  original_title          genre_ids  \
# 0             Avengers: Endgame      [28, 12, 878]
# 1                        Avatar  [28, 12, 14, 878]
# 2  Star Wars: The Force Awakens  [28, 12, 14, 878]
# 3        Avengers: Infinity War      [28, 12, 878]
# 4                Jurassic World  [28, 12, 878, 53]
#
#                           title  vote_average  \
# 0             Avengers: Endgame           8.3
# 1                        Avatar           7.4
# 2  Star Wars: The Force Awakens           7.4
# 3        Avengers: Infinity War           8.3
# ...

# %%
tmdb.genres[0]
# Out:
# "[{'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}]"

# %%
tmdb.genres= [eval(key) for key in tmdb.genres]
tmdb.production_companies= [eval(key) for key in tmdb.production_companies]
tmdb.production_countries= [eval(key) for key in tmdb.production_countries]

# %%
tmdb
# Out:
#       popularity  vote_count  video      id  adult original_language  \
# 0         40.636       14611  False  299534  False                en
# 1         36.426       21849  False   19995  False                en
# 2         31.247       14812  False  140607  False                en
# 3         82.930       19327  False  299536  False                en
# 4         30.958       15896  False  135397  False                en
# ...          ...         ...    ...     ...    ...               ...
# 5421       0.600           0  False  170053  False                en
# 5422       0.662           2  False  169867  False                en
# 5423       1.862           3  False   77591  False                en
# 5424       0.968           2  False   69767  False                en
# 5425       8.046         139  False   14424  False                en
#
#                                  original_title          genre_ids  \
# 0                             Avengers: Endgame      [28, 12, 878]
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-577d836af970> in <module>
# ----> 1 imdb= pd.read_json('imdb/title_essential_v1_sample.jsonl 2')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ...

# %%
# Out:
# <Response [403]>
